# %% [markdown]
# # Street View House Numbers
#
# SVHN is a real-world image dataset for developing machine learning and object recognition algorithms with minimal requirement on data preprocessing and formatting. It can be seen as similar in flavor to MNIST (e.g., the images are of small cropped digits), but incorporates an order of magnitude more labeled data (over 600,000 digit images) and comes from a significantly harder, unsolved, real world problem (recognizing digits and numbers in natural scene images). SVHN is obtained from house numbers in Google Street View images.
#
# These are the original, variable-resolution, color house-number images with character level bounding boxes, as shown in the examples images above. (The blue bounding boxes here are just for illustration purposes. The bounding box information are stored in digitStruct.mat instead of drawn directly on the images in the dataset.) Each tar.gz file contains the orignal images in png format, together with a digitStruct.mat file, which can be loaded using Matlab. The digitStruct.mat file contains a struct called digitStruct with the same length as the number of original images. Each element in digitStruct has the following fields: name which is a string containing the filename of the corresponding image. bbox which is a struct array that contains the position, size and label of each digit bounding box in the image. Eg: digitStruct(300).bbox(2).height gives height of the 2nd digit bounding box in the 300th image.
#
# * Dataset link:
# http://ufldl.stanford.edu/housenumbers/

# %%
To correctly detect a series of numbers given an image of house
numbers by training a convolutional neural network with multiple
layers.

# %% [markdown]
# ## Data Pre Processing

# %% [markdown]
# ### 1. Import Libraries

# %% [markdown]
# The future statement is intended to ease migration to future versions of Python that introduce incompatible changes to the language. It allows use of the new features on a per-module basis before the release in which the feature becomes standard.
# __future__ is a pseudo-module which programmers can use to enable new language features which are not compatible with the current interpreter. For example, the expression 11/4 currently evaluates to 2. If the module in which it is executed had enabled true division by executing:
#
# from __future__ import division
#
# the expression 11/4 would evaluate to 2.75.
# from __future__ import print_function
#
#
# * six
# Six is a Python 2 and 3 compatibility library. It provides utility functions for smoothing over the differences between the Python versions with the goal of writing Python code that is compatible on both Python versions.

# %%
#from six.moves import cPickle as pickle
#from six.moves import range
#from six.moves.urllib.request import urlretrieve
#from urllib.request import urlretrieve
import pickle
from IPython.display import display, Image
#from scipy import ndimage
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
#import os
#import sys
#import tarfile
import h5py

# %%
tf.__version__
# Out:
# '1.6.0'

# %%
train_folder = '/train'
test_folder ='/test'
extra_folder = '/extra'

# %%
pwd
# Out:
# 'F:\\Aegis\\Python\\Jupyter Notebook\\Projects\\SVHM'

# %%
### 1. Creating Dictionary for bounded box information
# Out:
# The filename, directory name, or volume label syntax is incorrect.

# %% [markdown]
# ##### h5 file
#
# An H5 file is a data file saved in the Hierarchical Data Format (HDF). It contains multidimensional arrays of scientific data. ... Two commonly used versions of HDF include HDF4 and HDF5
#
# ##### HDF5 for Python
# The h5py package is a Pythonic interface to the HDF5 binary data format.
#
# It lets you store huge amounts of numerical data, and easily manipulate that data from NumPy. For example, you can slice into multi-terabyte datasets stored on disk, as if they were real NumPy arrays. Thousands of datasets can be stored in a single file, categorized and tagged however you want.
#
# H5py uses straightforward NumPy and Python metaphors, like dictionary and NumPy array syntax.
#
# mat files are actually saved using the HDF5 format by default

# %% [raw]
# #Throws NotImplementedError: Please use HDF reader for matlab v7.3 files
#
# import scipy.io
# digitMat = scipy.io.loadmat('./train/digitStruct.mat')

# %%
import numpy as np
import h5py
struct_file = './train/digitStruct.mat'
file = h5py.File(struct_file,'r')
data = file.get('/digitStruct/name').value[0].item()
d2 = np.array(data)
d2
# Out:
# array(<HDF5 object reference>, dtype=object)

# %%
import numpy as np
import h5py

with h5py.File('./train/digitStruct.mat','r') as hdf:
    ls = list(hdf.keys())
    print(" List of dataset in this file is ",ls)
    data = hdf.get('/digitStruct/name')
    data1 = hdf.get('/digitStruct/bbox')
    d1 = np.array(data)
    d2 = np.array(data1)
    print(" Shape of file is ",d1.shape)
    print(" Shape of file is ",d2.shape)
# Out:
#  List of dataset in this file is  ['#refs#', 'digitStruct']
#  Shape of file is  (33402, 1)
#  Shape of file is  (33402, 1)

# %%
doubt -- .value[1][0]

# %%
import h5py
struct_file = './train/digitStruct.mat'
file = h5py.File(struct_file)
name = file.get('/digitStruct/name').value[1][0] # <HDF5 object reference>
bbox = file.get('/digitStruct/bbox').value[1][0]
print("name data",file[name].value)
print("box data",file[bbox])
# Out:
# name data [[ 50]
#  [ 46]
#  [112]
#  [110]
#  [103]]
# box data <HDF5 group "/#refs#/7Qi" (5 members)>

# %%
a = file[file['digitStruct']['name'][1][0]]
print(a)
a = file[file['digitStruct']['name'][1][0]].value
print(a)

# %%
''.join([chr(c[0]) for c in a])
# Out:
# '2.png'

# %%
for c in a:
    print(c[0]," :",chr(c[0]))
# Out:
# 50  : 2
# 46  : .
# 112  : p
# 110  : n
# 103  : g

# %%
chr(97)
# Out:
# 'a'

# %%
file[file['digitStruct']['bbox'][0].item()]['height']
# Out:
# <HDF5 dataset "height": shape (2, 1), type "|O">

# %%
len(file['digitStruct']['name'])
# Out:
# 33402

# %%
p=1
class DigitStructFile:
    '''The DigitStructFile references the following 
    file:              The input h5 matlab file
    digitStructName   The h5 reference to all the file names
    digitStructBbox   The h5 reference to all struc data'''
    def __init__(self,file):
        self.file = h5py.File(file, 'r') #Create a new file object.
        self.digitStructName = self.file['digitStruct']['name']
        self.digitStructBox = self.file['digitStruct']['bbox']
        
    def getName(self,n):
        '''Returns name string for the nth digitStruct '''
        '''Naming of files start from index 0(1.png) and file name is stored not directly as filename but in Ascii value 
        A-65, a-97 and so on'''
        return ''.join([chr(c[0]) for c in self.file[self.digitStructName[n][0]].value])
    
    def bboxHelper(self,attr):
        print("In box helper")
        if len(attr) > 1: #check if image has more than one digits by checking len of height,label,top,left 
            attr = [self.file[attr.value[j].item()].value[0][0] for j in range(len(attr))]
            print("in If ",attr)
        else: #eg image 21.png has only 1 digit ie 2
            attr = [attr.value[0][0]]
            print("in Else ",attr)
        return attr
    
    def getBbox(self,n):
        '''Returns a dict of box data for the n(th) bbox '''
        bbox ={}
        print("n = ",n)
        bb = self.digitStructBox[n].item()
        print("BB ",bb)
        bbox['height'] = self.bboxHelper(self.file[bb]['height'])
        bbox['label'] = self.bboxHelper(self.file[bb]['label'])
        bbox['left'] = self.bboxHelper(self.file[bb]['left'])
        bbox['top'] = self.bboxHelper(self.file[bb]['top'])
        bbox['width'] = self.bboxHelper(self.file[bb]['width'])
        print("bbox returned by getBbox ",bbox)
        return bbox
    
    def getDigitStruct(self,n):
        '''Returns a dictionary of digit structure info , eg for n=0
        {'label': [1.0, 9.0], 'height': [219.0, 219.0], 'top': [77.0, 81.0], 'width': [81.0, 96.0], 'left': [246.0, 323.0]} 
        for n=20  {'label': [2.0], 'height': [85.0], 'top': [6.0], 'width': [52.0], 'left': [72.0]} '''
        struct = self.getBbox(n) #returns dict of boxes
        struct['name'] = self.getName(n)
        return struct
    
    def getAllDigitStruct(self):
        '''Returns all the digitStruct from the input file'''
        return [self.getDigitStruct(i) for i in range(len(self.digitStructName))]
    
    def getAllDigitStruct_Digit(self):
        '''We just rearrange the output generated by getAllDigitStruct() as shown below'''
        '''Returns a list containing info of each file in dict format of keys boxes and filename. 
        boxes is a list of dicts , the first record is 
        {'boxes': [{'height': 219.0,'label': 1.0, 'left': 246.0,'top': 77.0,'width': 81.0},
                   {'height': 219.0, 'label': 9.0, 'left': 323.0, 'top': 81.0, 'width': 96.0}],
        'filename': '1.png'}   '''
        digit_pic = self.getAllDigitStruct()
        result=[]
        structCnt = 1
        for i in range(len(digit_pic)):
            item = {'filename':digit_pic[i]['name']}
            figures=[]
            for j in range(len(digit_pic[i]['height'])):
                figure = {}
                figure['height'] = digit_pic[i]['height'][j]
                figure['label'] = digit_pic[i]['label'][j]
                figure['left'] = digit_pic[i]['left'][j]
                figure['top'] = digit_pic[i]['top'][j]
                figure['width'] = digit_pic[i]['width'][j]
                figures.append(figure)
            structCnt+=1
            item['boxes'] = figures
            result.append(item)
            print("Result FInal ",result)
        return result

# %%
import datetime

digitStructFileTrain = DigitStructFile(os.path.join('train','digitStruct.mat'))
#digitStructFileTest = DigitStructFile(os.path.join('test','digitStruct.mat'))
#digitStructFileExtra = DigitStructFile(os.path.join('extra','digitStruct.mat'))

print("Start of Processing Data ",datetime.datetime.now())
train_data = digitStructFileTrain.getAllDigitStruct_Digit()
#test_data = digitStructFileTest.getAllDigitStruct_Digit()
#extra_data = digitStructFileExtra.getAllDigitStruct_Digit()

print("End of Processing Data ",datetime.datetime.now())
# Out:
# Start of Processing Data  2019-04-16 23:22:14.238453
# n =  0
# BB  <HDF5 object reference>
# In box helper
# in If  [219.0, 219.0]
# In box helper
# in If  [1.0, 9.0]
# In box helper
# in If  [246.0, 323.0]
# In box helper
# in If  [77.0, 81.0]
# In box helper
# in If  [81.0, 96.0]
# bbox returned by getBbox  {'label': [1.0, 9.0], 'height': [219.0, 219.0], 'top': [77.0, 81.0], 'width': [81.0, 96.0], 'left': [246.0, 323.0]}
# n =  1
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0]
# In box helper
# in If  [2.0, 3.0]
# In box helper
# in If  [77.0, 98.0]
# In box helper
# in If  [29.0, 25.0]
# In box helper
# in If  [23.0, 26.0]
# bbox returned by getBbox  {'label': [2.0, 3.0], 'height': [32.0, 32.0], 'top': [29.0, 25.0], 'width': [23.0, 26.0], 'left': [77.0, 98.0]}
# n =  2
# BB  <HDF5 object reference>
# In box helper
# in If  [15.0, 15.0]
# In box helper
# in If  [2.0, 5.0]
# In box helper
# in If  [17.0, 25.0]
# In box helper
# in If  [5.0, 5.0]
# In box helper
# in If  [8.0, 9.0]
# bbox returned by getBbox  {'label': [2.0, 5.0], 'height': [15.0, 15.0], 'top': [5.0, 5.0], 'width': [8.0, 9.0], 'left': [17.0, 25.0]}
# n =  3
# BB  <HDF5 object reference>
# In box helper
# in If  [34.0, 34.0]
# In box helper
# in If  [9.0, 3.0]
# In box helper
# in If  [57.0, 72.0]
# In box helper
# in If  [13.0, 13.0]
# In box helper
# in If  [15.0, 13.0]
# bbox returned by getBbox  {'label': [9.0, 3.0], 'height': [34.0, 34.0], 'top': [13.0, 13.0], 'width': [15.0, 13.0], 'left': [57.0, 72.0]}
# n =  4
# BB  <HDF5 object reference>
# In box helper
# in If  [46.0, 46.0]
# In box helper
# in If  [3.0, 1.0]
# In box helper
# in If  [52.0, 74.0]
# In box helper
# in If  [7.0, 10.0]
# In box helper
# in If  [21.0, 15.0]
# bbox returned by getBbox  {'label': [3.0, 1.0], 'height': [46.0, 46.0], 'top': [7.0, 10.0], 'width': [21.0, 15.0], 'left': [52.0, 74.0]}
# n =  5
# BB  <HDF5 object reference>
# In box helper
# in If  [21.0, 21.0]
# In box helper
# in If  [3.0, 3.0]
# In box helper
# in If  [28.0, 38.0]
# In box helper
# in If  [6.0, 8.0]
# In box helper
# in If  [10.0, 11.0]
# bbox returned by getBbox  {'label': [3.0, 3.0], 'height': [21.0, 21.0], 'top': [6.0, 8.0], 'width': [10.0, 11.0], 'left': [28.0, 38.0]}
# n =  6
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0]
# In box helper
# in If  [2.0, 8.0]
# In box helper
# in If  [35.0, 47.0]
# In box helper
# in If  [10.0, 11.0]
# In box helper
# in If  [13.0, 13.0]
# bbox returned by getBbox  {'label': [2.0, 8.0], 'height': [32.0, 32.0], 'top': [10.0, 11.0], 'width': [13.0, 13.0], 'left': [35.0, 47.0]}
# n =  7
# BB  <HDF5 object reference>
# In box helper
# in If  [15.0, 15.0, 15.0]
# In box helper
# in If  [7.0, 4.0, 4.0]
# In box helper
# in If  [17.0, 25.0, 31.0]
# In box helper
# in If  [4.0, 4.0, 3.0]
# In box helper
# in If  [7.0, 6.0, 7.0]
# bbox returned by getBbox  {'label': [7.0, 4.0, 4.0], 'height': [15.0, 15.0, 15.0], 'top': [4.0, 4.0, 3.0], 'width': [7.0, 6.0, 7.0], 'left': [17.0, 25.0, 31.0]}
# n =  8
# BB  <HDF5 object reference>
# In box helper
# in If  [24.0, 24.0, 24.0]
# In box helper
# in If  [1.0, 2.0, 8.0]
# In box helper
# in If  [19.0, 29.0, 38.0]
# In box helper
# in If  [4.0, 4.0, 5.0]
# In box helper
# in If  [14.0, 13.0, 17.0]
# bbox returned by getBbox  {'label': [1.0, 2.0, 8.0], 'height': [24.0, 24.0, 24.0], 'top': [4.0, 4.0, 5.0], 'width': [14.0, 13.0, 17.0], 'left': [19.0, 29.0, 38.0]}
# n =  9
# BB  <HDF5 object reference>
# In box helper
# in If  [27.0, 27.0]
# In box helper
# in If  [1.0, 6.0]
# In box helper
# in If  [25.0, 34.0]
# In box helper
# in If  [6.0, 4.0]
# In box helper
# in If  [9.0, 14.0]
# bbox returned by getBbox  {'label': [1.0, 6.0], 'height': [27.0, 27.0], 'top': [6.0, 4.0], 'width': [9.0, 14.0], 'left': [25.0, 34.0]}
# n =  10
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0]
# In box helper
# in If  [2.0, 3.0]
# In box helper
# in If  [22.0, 33.0]
# In box helper
# in If  [5.0, 4.0]
# In box helper
# in If  [12.0, 9.0]
# bbox returned by getBbox  {'label': [2.0, 3.0], 'height': [26.0, 26.0], 'top': [5.0, 4.0], 'width': [12.0, 9.0], 'left': [22.0, 33.0]}
# n =  11
# BB  <HDF5 object reference>
# In box helper
# in If  [55.0, 55.0]
# In box helper
# in If  [6.0, 3.0]
# In box helper
# in If  [67.0, 90.0]
# In box helper
# in If  [16.0, 17.0]
# In box helper
# in If  [23.0, 20.0]
# bbox returned by getBbox  {'label': [6.0, 3.0], 'height': [55.0, 55.0], 'top': [16.0, 17.0], 'width': [23.0, 20.0], 'left': [67.0, 90.0]}
# n =  12
# BB  <HDF5 object reference>
# In box helper
# in If  [33.0, 33.0]
# In box helper
# in If  [4.0, 2.0]
# In box helper
# in If  [44.0, 63.0]
# In box helper
# in If  [12.0, 13.0]
# In box helper
# in If  [17.0, 18.0]
# bbox returned by getBbox  {'label': [4.0, 2.0], 'height': [33.0, 33.0], 'top': [12.0, 13.0], 'width': [17.0, 18.0], 'left': [44.0, 63.0]}
# n =  13
# BB  <HDF5 object reference>
# In box helper
# in If  [42.0, 42.0]
# In box helper
# in If  [5.0, 8.0]
# In box helper
# in If  [35.0, 55.0]
# In box helper
# in If  [2.0, 2.0]
# In box helper
# in If  [21.0, 23.0]
# bbox returned by getBbox  {'label': [5.0, 8.0], 'height': [42.0, 42.0], 'top': [2.0, 2.0], 'width': [21.0, 23.0], 'left': [35.0, 55.0]}
# n =  14
# BB  <HDF5 object reference>
# In box helper
# in If  [20.0, 20.0]
# In box helper
# in If  [1.0, 6.0]
# In box helper
# in If  [22.0, 33.0]
# In box helper
# in If  [8.0, 7.0]
# In box helper
# in If  [14.0, 10.0]
# bbox returned by getBbox  {'label': [1.0, 6.0], 'height': [20.0, 20.0], 'top': [8.0, 7.0], 'width': [14.0, 10.0], 'left': [22.0, 33.0]}
# n =  15
# BB  <HDF5 object reference>
# In box helper
# in If  [19.0, 19.0]
# In box helper
# in If  [2.0, 3.0]
# In box helper
# in If  [20.0, 26.0]
# In box helper
# in If  [3.0, 1.0]
# In box helper
# in If  [7.0, 7.0]
# bbox returned by getBbox  {'label': [2.0, 3.0], 'height': [19.0, 19.0], 'top': [3.0, 1.0], 'width': [7.0, 7.0], 'left': [20.0, 26.0]}
# n =  16
# BB  <HDF5 object reference>
# In box helper
# in If  [22.0, 22.0]
# In box helper
# in If  [7.0, 9.0]
# In box helper
# in If  [23.0, 35.0]
# In box helper
# in If  [4.0, 4.0]
# In box helper
# in If  [14.0, 12.0]
# bbox returned by getBbox  {'label': [7.0, 9.0], 'height': [22.0, 22.0], 'top': [4.0, 4.0], 'width': [14.0, 12.0], 'left': [23.0, 35.0]}
# n =  17
# BB  <HDF5 object reference>
# In box helper
# in If  [41.0, 41.0]
# In box helper
# in If  [5.0, 3.0]
# In box helper
# in If  [52.0, 80.0]
# In box helper
# in If  [12.0, 17.0]
# In box helper
# in If  [28.0, 21.0]
# bbox returned by getBbox  {'label': [5.0, 3.0], 'height': [41.0, 41.0], 'top': [12.0, 17.0], 'width': [28.0, 21.0], 'left': [52.0, 80.0]}
# n =  18
# BB  <HDF5 object reference>
# In box helper
# in If  [19.0, 19.0, 19.0]
# In box helper
# in If  [2.0, 2.0, 2.0]
# In box helper
# in If  [19.0, 28.0, 36.0]
# In box helper
# in If  [1.0, 1.0, 1.0]
# In box helper
# in If  [7.0, 7.0, 7.0]
# bbox returned by getBbox  {'label': [2.0, 2.0, 2.0], 'height': [19.0, 19.0, 19.0], 'top': [1.0, 1.0, 1.0], 'width': [7.0, 7.0, 7.0], 'left': [19.0, 28.0, 36.0]}
# n =  19
# BB  <HDF5 object reference>
# In box helper
# in If  [24.0, 24.0]
# In box helper
# in If  [6.0, 2.0]
# In box helper
# in If  [20.0, 32.0]
# In box helper
# in If  [2.0, 1.0]
# In box helper
# in If  [11.0, 11.0]
# bbox returned by getBbox  {'label': [6.0, 2.0], 'height': [24.0, 24.0], 'top': [2.0, 1.0], 'width': [11.0, 11.0], 'left': [20.0, 32.0]}
# n =  20
# BB  <HDF5 object reference>
# In box helper
# in Else  [85.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [72.0]
# In box helper
# in Else  [6.0]
# In box helper
# in Else  [52.0]
# bbox returned by getBbox  {'label': [2.0], 'height': [85.0], 'top': [6.0], 'width': [52.0], 'left': [72.0]}
# n =  21
# BB  <HDF5 object reference>
# In box helper
# in If  [16.0, 16.0, 16.0]
# In box helper
# in If  [5.0, 1.0, 5.0]
# In box helper
# in If  [24.0, 34.0, 40.0]
# In box helper
# in If  [4.0, 5.0, 5.0]
# In box helper
# in If  [10.0, 7.0, 11.0]
# bbox returned by getBbox  {'label': [5.0, 1.0, 5.0], 'height': [16.0, 16.0, 16.0], 'top': [4.0, 5.0, 5.0], 'width': [10.0, 7.0, 11.0], 'left': [24.0, 34.0, 40.0]}
# n =  22
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0]
# In box helper
# in If  [4.0, 7.0]
# In box helper
# in If  [29.0, 52.0]
# In box helper
# in If  [5.0, 5.0]
# In box helper
# in If  [21.0, 22.0]
# bbox returned by getBbox  {'label': [4.0, 7.0], 'height': [32.0, 32.0], 'top': [5.0, 5.0], 'width': [21.0, 22.0], 'left': [29.0, 52.0]}
# n =  23
# BB  <HDF5 object reference>
# In box helper
# in If  [34.0, 34.0]
# In box helper
# in If  [8.0, 9.0]
# In box helper
# in If  [233.0, 248.0]
# In box helper
# in If  [59.0, 56.0]
# In box helper
# in If  [19.0, 21.0]
# bbox returned by getBbox  {'label': [8.0, 9.0], 'height': [34.0, 34.0], 'top': [59.0, 56.0], 'width': [19.0, 21.0], 'left': [233.0, 248.0]}
# n =  24
# BB  <HDF5 object reference>
# In box helper
# in If  [50.0, 50.0, 50.0]
# In box helper
# in If  [6.0, 10.0, 1.0]
# In box helper
# in If  [60.0, 87.0, 113.0]
# In box helper
# in If  [11.0, 9.0, 7.0]
# In box helper
# in If  [24.0, 24.0, 21.0]
# bbox returned by getBbox  {'label': [6.0, 10.0, 1.0], 'height': [50.0, 50.0, 50.0], 'top': [11.0, 9.0, 7.0], 'width': [24.0, 24.0, 21.0], 'left': [60.0, 87.0, 113.0]}
# n =  25
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0]
# In box helper
# in If  [2.0, 4.0]
# In box helper
# in If  [34.0, 49.0]
# In box helper
# in If  [7.0, 8.0]
# In box helper
# in If  [12.0, 13.0]
# bbox returned by getBbox  {'label': [2.0, 4.0], 'height': [32.0, 32.0], 'top': [7.0, 8.0], 'width': [12.0, 13.0], 'left': [34.0, 49.0]}
# n =  26
# BB  <HDF5 object reference>
# In box helper
# in If  [45.0, 45.0]
# In box helper
# in If  [5.0, 6.0]
# In box helper
# in If  [46.0, 73.0]
# In box helper
# in If  [11.0, 8.0]
# In box helper
# in If  [26.0, 27.0]
# bbox returned by getBbox  {'label': [5.0, 6.0], 'height': [45.0, 45.0], 'top': [11.0, 8.0], 'width': [26.0, 27.0], 'left': [46.0, 73.0]}
# n =  27
# BB  <HDF5 object reference>
# In box helper
# in If  [33.0, 33.0]
# In box helper
# in If  [5.0, 2.0]
# In box helper
# in If  [31.0, 42.0]
# In box helper
# in If  [8.0, 7.0]
# In box helper
# in If  [13.0, 10.0]
# bbox returned by getBbox  {'label': [5.0, 2.0], 'height': [33.0, 33.0], 'top': [8.0, 7.0], 'width': [13.0, 10.0], 'left': [31.0, 42.0]}
# n =  28
# BB  <HDF5 object reference>
# In box helper
# in If  [18.0, 18.0, 18.0]
# In box helper
# in If  [1.0, 3.0, 2.0]
# In box helper
# in If  [43.0, 51.0, 66.0]
# In box helper
# in If  [14.0, 13.0, 14.0]
# In box helper
# in If  [10.0, 16.0, 5.0]
# bbox returned by getBbox  {'label': [1.0, 3.0, 2.0], 'height': [18.0, 18.0, 18.0], 'top': [14.0, 13.0, 14.0], 'width': [10.0, 16.0, 5.0], 'left': [43.0, 51.0, 66.0]}
# n =  29
# BB  <HDF5 object reference>
# In box helper
# in If  [25.0, 25.0]
# In box helper
# in If  [1.0, 4.0]
# In box helper
# in If  [16.0, 25.0]
# In box helper
# in If  [1.0, 1.0]
# In box helper
# in If  [7.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 4.0], 'height': [25.0, 25.0], 'top': [1.0, 1.0], 'width': [7.0, 11.0], 'left': [16.0, 25.0]}
# n =  30
# BB  <HDF5 object reference>
# In box helper
# in If  [19.0, 19.0, 19.0]
# In box helper
# in If  [6.0, 3.0, 8.0]
# In box helper
# in If  [14.0, 24.0, 36.0]
# In box helper
# in If  [1.0, 1.0, 1.0]
# In box helper
# in If  [10.0, 11.0, 11.0]
# bbox returned by getBbox  {'label': [6.0, 3.0, 8.0], 'height': [19.0, 19.0, 19.0], 'top': [1.0, 1.0, 1.0], 'width': [10.0, 11.0, 11.0], 'left': [14.0, 24.0, 36.0]}
# n =  31
# BB  <HDF5 object reference>
# In box helper
# in If  [33.0, 33.0]
# In box helper
# in If  [4.0, 3.0]
# In box helper
# in If  [48.0, 67.0]
# In box helper
# in If  [16.0, 19.0]
# In box helper
# in If  [17.0, 18.0]
# bbox returned by getBbox  {'label': [4.0, 3.0], 'height': [33.0, 33.0], 'top': [16.0, 19.0], 'width': [17.0, 18.0], 'left': [48.0, 67.0]}
# n =  32
# BB  <HDF5 object reference>
# In box helper
# in If  [33.0, 33.0]
# In box helper
# in If  [1.0, 4.0]
# In box helper
# in If  [27.0, 42.0]
# In box helper
# in If  [5.0, 5.0]
# In box helper
# in If  [16.0, 18.0]
# bbox returned by getBbox  {'label': [1.0, 4.0], 'height': [33.0, 33.0], 'top': [5.0, 5.0], 'width': [16.0, 18.0], 'left': [27.0, 42.0]}
# n =  33
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0]
# In box helper
# in If  [4.0, 2.0]
# In box helper
# in If  [41.0, 54.0]
# In box helper
# in If  [13.0, 9.0]
# In box helper
# in If  [16.0, 24.0]
# bbox returned by getBbox  {'label': [4.0, 2.0], 'height': [32.0, 32.0], 'top': [13.0, 9.0], 'width': [16.0, 24.0], 'left': [41.0, 54.0]}
# n =  34
# BB  <HDF5 object reference>
# In box helper
# in Else  [14.0]
# In box helper
# in Else  [6.0]
# In box helper
# in Else  [25.0]
# In box helper
# in Else  [5.0]
# In box helper
# in Else  [7.0]
# bbox returned by getBbox  {'label': [6.0], 'height': [14.0], 'top': [5.0], 'width': [7.0], 'left': [25.0]}
# n =  35
# BB  <HDF5 object reference>
# In box helper
# in If  [47.0, 47.0]
# In box helper
# in If  [4.0, 4.0]
# In box helper
# in If  [50.0, 72.0]
# In box helper
# in If  [9.0, 8.0]
# In box helper
# in If  [23.0, 24.0]
# bbox returned by getBbox  {'label': [4.0, 4.0], 'height': [47.0, 47.0], 'top': [9.0, 8.0], 'width': [23.0, 24.0], 'left': [50.0, 72.0]}
# n =  36
# BB  <HDF5 object reference>
# In box helper
# in If  [20.0, 20.0]
# In box helper
# in If  [1.0, 1.0]
# In box helper
# in If  [24.0, 42.0]
# In box helper
# in If  [4.0, 2.0]
# In box helper
# in If  [6.0, 7.0]
# bbox returned by getBbox  {'label': [1.0, 1.0], 'height': [20.0, 20.0], 'top': [4.0, 2.0], 'width': [6.0, 7.0], 'left': [24.0, 42.0]}
# n =  37
# BB  <HDF5 object reference>
# In box helper
# in If  [57.0, 57.0]
# In box helper
# in If  [1.0, 7.0]
# In box helper
# in If  [87.0, 108.0]
# In box helper
# in If  [28.0, 22.0]
# In box helper
# in If  [26.0, 37.0]
# bbox returned by getBbox  {'label': [1.0, 7.0], 'height': [57.0, 57.0], 'top': [28.0, 22.0], 'width': [26.0, 37.0], 'left': [87.0, 108.0]}
# n =  38
# BB  <HDF5 object reference>
# In box helper
# in If  [40.0, 40.0]
# In box helper
# in If  [3.0, 1.0]
# In box helper
# in If  [62.0, 74.0]
# In box helper
# in If  [19.0, 20.0]
# In box helper
# in If  [13.0, 9.0]
# bbox returned by getBbox  {'label': [3.0, 1.0], 'height': [40.0, 40.0], 'top': [19.0, 20.0], 'width': [13.0, 9.0], 'left': [62.0, 74.0]}
# n =  39
# BB  <HDF5 object reference>
# In box helper
# in If  [61.0, 61.0]
# In box helper
# in If  [2.0, 10.0]
# In box helper
# in If  [61.0, 93.0]
# In box helper
# in If  [9.0, 17.0]
# In box helper
# in If  [28.0, 28.0]
# bbox returned by getBbox  {'label': [2.0, 10.0], 'height': [61.0, 61.0], 'top': [9.0, 17.0], 'width': [28.0, 28.0], 'left': [61.0, 93.0]}
# n =  40
# BB  <HDF5 object reference>
# In box helper
# in If  [35.0, 35.0]
# In box helper
# in If  [4.0, 2.0]
# In box helper
# in If  [38.0, 50.0]
# In box helper
# in If  [10.0, 9.0]
# In box helper
# in If  [11.0, 13.0]
# bbox returned by getBbox  {'label': [4.0, 2.0], 'height': [35.0, 35.0], 'top': [10.0, 9.0], 'width': [11.0, 13.0], 'left': [38.0, 50.0]}
# n =  41
# BB  <HDF5 object reference>
# In box helper
# in If  [51.0, 51.0, 51.0]
# In box helper
# in If  [2.0, 5.0, 1.0]
# In box helper
# in If  [110.0, 131.0, 159.0]
# In box helper
# in If  [27.0, 36.0, 36.0]
# In box helper
# in If  [25.0, 30.0, 26.0]
# bbox returned by getBbox  {'label': [2.0, 5.0, 1.0], 'height': [51.0, 51.0, 51.0], 'top': [27.0, 36.0, 36.0], 'width': [25.0, 30.0, 26.0], 'left': [110.0, 131.0, 159.0]}
# n =  42
# BB  <HDF5 object reference>
# In box helper
# in If  [51.0, 51.0]
# In box helper
# in If  [2.0, 9.0]
# In box helper
# in If  [87.0, 119.0]
# In box helper
# in If  [24.0, 20.0]
# In box helper
# in If  [31.0, 26.0]
# bbox returned by getBbox  {'label': [2.0, 9.0], 'height': [51.0, 51.0], 'top': [24.0, 20.0], 'width': [31.0, 26.0], 'left': [87.0, 119.0]}
# n =  43
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0, 26.0]
# In box helper
# in If  [2.0, 10.0, 4.0]
# In box helper
# in If  [19.0, 32.0, 40.0]
# In box helper
# in If  [3.0, 3.0, 3.0]
# In box helper
# in If  [13.0, 8.0, 7.0]
# bbox returned by getBbox  {'label': [2.0, 10.0, 4.0], 'height': [26.0, 26.0, 26.0], 'top': [3.0, 3.0, 3.0], 'width': [13.0, 8.0, 7.0], 'left': [19.0, 32.0, 40.0]}
# n =  44
# BB  <HDF5 object reference>
# In box helper
# in If  [31.0, 31.0]
# In box helper
# in If  [1.0, 10.0]
# In box helper
# in If  [35.0, 44.0]
# In box helper
# in If  [3.0, 4.0]
# In box helper
# in If  [8.0, 12.0]
# bbox returned by getBbox  {'label': [1.0, 10.0], 'height': [31.0, 31.0], 'top': [3.0, 4.0], 'width': [8.0, 12.0], 'left': [35.0, 44.0]}
# n =  45
# BB  <HDF5 object reference>
# In box helper
# in If  [104.0, 104.0, 104.0]
# In box helper
# in If  [3.0, 2.0, 7.0]
# In box helper
# in If  [136.0, 201.0, 257.0]
# In box helper
# in If  [87.0, 44.0, 18.0]
# In box helper
# in If  [49.0, 41.0, 53.0]
# bbox returned by getBbox  {'label': [3.0, 2.0, 7.0], 'height': [104.0, 104.0, 104.0], 'top': [87.0, 44.0, 18.0], 'width': [49.0, 41.0, 53.0], 'left': [136.0, 201.0, 257.0]}
# n =  46
# BB  <HDF5 object reference>
# In box helper
# in If  [15.0, 15.0]
# In box helper
# in If  [2.0, 4.0]
# In box helper
# in If  [14.0, 20.0]
# In box helper
# in If  [2.0, 1.0]
# In box helper
# in If  [6.0, 5.0]
# bbox returned by getBbox  {'label': [2.0, 4.0], 'height': [15.0, 15.0], 'top': [2.0, 1.0], 'width': [6.0, 5.0], 'left': [14.0, 20.0]}
# n =  47
# BB  <HDF5 object reference>
# In box helper
# in If  [50.0, 50.0]
# In box helper
# in If  [4.0, 6.0]
# In box helper
# in If  [74.0, 103.0]
# In box helper
# in If  [20.0, 17.0]
# In box helper
# in If  [28.0, 29.0]
# bbox returned by getBbox  {'label': [4.0, 6.0], 'height': [50.0, 50.0], 'top': [20.0, 17.0], 'width': [28.0, 29.0], 'left': [74.0, 103.0]}
# n =  48
# BB  <HDF5 object reference>
# In box helper
# in If  [45.0, 45.0, 45.0]
# In box helper
# in If  [8.0, 1.0, 7.0]
# In box helper
# in If  [65.0, 102.0, 132.0]
# In box helper
# in If  [18.0, 15.0, 16.0]
# In box helper
# in If  [36.0, 26.0, 28.0]
# bbox returned by getBbox  {'label': [8.0, 1.0, 7.0], 'height': [45.0, 45.0, 45.0], 'top': [18.0, 15.0, 16.0], 'width': [36.0, 26.0, 28.0], 'left': [65.0, 102.0, 132.0]}
# n =  49
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0, 26.0]
# In box helper
# in If  [1.0, 10.0, 3.0]
# In box helper
# in If  [58.0, 74.0, 95.0]
# In box helper
# in If  [27.0, 22.0, 17.0]
# In box helper
# in If  [11.0, 15.0, 15.0]
# bbox returned by getBbox  {'label': [1.0, 10.0, 3.0], 'height': [26.0, 26.0, 26.0], 'top': [27.0, 22.0, 17.0], 'width': [11.0, 15.0, 15.0], 'left': [58.0, 74.0, 95.0]}
# n =  50
# BB  <HDF5 object reference>
# In box helper
# in If  [45.0, 45.0]
# In box helper
# in If  [9.0, 1.0]
# In box helper
# in If  [47.0, 66.0]
# In box helper
# in If  [7.0, 9.0]
# In box helper
# in If  [16.0, 9.0]
# bbox returned by getBbox  {'label': [9.0, 1.0], 'height': [45.0, 45.0], 'top': [7.0, 9.0], 'width': [16.0, 9.0], 'left': [47.0, 66.0]}
# n =  51
# BB  <HDF5 object reference>
# In box helper
# in If  [38.0, 38.0]
# In box helper
# in If  [3.0, 5.0]
# In box helper
# in If  [45.0, 74.0]
# In box helper
# in If  [12.0, 11.0]
# In box helper
# in If  [23.0, 28.0]
# bbox returned by getBbox  {'label': [3.0, 5.0], 'height': [38.0, 38.0], 'top': [12.0, 11.0], 'width': [23.0, 28.0], 'left': [45.0, 74.0]}
# n =  52
# BB  <HDF5 object reference>
# In box helper
# in If  [84.0, 84.0]
# In box helper
# in If  [9.0, 3.0]
# In box helper
# in If  [160.0, 208.0]
# In box helper
# in If  [34.0, 18.0]
# In box helper
# in If  [59.0, 52.0]
# bbox returned by getBbox  {'label': [9.0, 3.0], 'height': [84.0, 84.0], 'top': [34.0, 18.0], 'width': [59.0, 52.0], 'left': [160.0, 208.0]}
# n =  53
# BB  <HDF5 object reference>
# In box helper
# in If  [45.0, 45.0]
# In box helper
# in If  [1.0, 1.0]
# In box helper
# in If  [36.0, 56.0]
# In box helper
# in If  [10.0, 8.0]
# In box helper
# in If  [18.0, 21.0]
# bbox returned by getBbox  {'label': [1.0, 1.0], 'height': [45.0, 45.0], 'top': [10.0, 8.0], 'width': [18.0, 21.0], 'left': [36.0, 56.0]}
# n =  54
# BB  <HDF5 object reference>
# In box helper
# in If  [35.0, 35.0, 35.0, 35.0]
# In box helper
# in If  [1.0, 1.0, 3.0, 7.0]
# In box helper
# in If  [116.0, 128.0, 137.0, 151.0]
# In box helper
# in If  [27.0, 29.0, 29.0, 26.0]
# In box helper
# in If  [15.0, 10.0, 17.0, 17.0]
# bbox returned by getBbox  {'label': [1.0, 1.0, 3.0, 7.0], 'height': [35.0, 35.0, 35.0, 35.0], 'top': [27.0, 29.0, 29.0, 26.0], 'width': [15.0, 10.0, 17.0, 17.0], 'left': [116.0, 128.0, 137.0, 151.0]}
# n =  55
# BB  <HDF5 object reference>
# In box helper
# in If  [20.0, 20.0]
# In box helper
# in If  [5.0, 6.0]
# In box helper
# in If  [22.0, 35.0]
# In box helper
# in If  [4.0, 3.0]
# In box helper
# in If  [9.0, 9.0]
# bbox returned by getBbox  {'label': [5.0, 6.0], 'height': [20.0, 20.0], 'top': [4.0, 3.0], 'width': [9.0, 9.0], 'left': [22.0, 35.0]}
# n =  56
# BB  <HDF5 object reference>
# In box helper
# in If  [25.0, 25.0, 25.0]
# In box helper
# in If  [2.0, 1.0, 5.0]
# In box helper
# in If  [63.0, 74.0, 83.0]
# In box helper
# in If  [38.0, 26.0, 12.0]
# In box helper
# in If  [16.0, 15.0, 19.0]
# bbox returned by getBbox  {'label': [2.0, 1.0, 5.0], 'height': [25.0, 25.0, 25.0], 'top': [38.0, 26.0, 12.0], 'width': [16.0, 15.0, 19.0], 'left': [63.0, 74.0, 83.0]}
# n =  57
# BB  <HDF5 object reference>
# In box helper
# in If  [46.0, 46.0]
# In box helper
# in If  [1.0, 1.0]
# In box helper
# in If  [45.0, 65.0]
# In box helper
# in If  [6.0, 2.0]
# In box helper
# in If  [19.0, 17.0]
# bbox returned by getBbox  {'label': [1.0, 1.0], 'height': [46.0, 46.0], 'top': [6.0, 2.0], 'width': [19.0, 17.0], 'left': [45.0, 65.0]}
# n =  58
# BB  <HDF5 object reference>
# In box helper
# in Else  [42.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [35.0]
# In box helper
# in Else  [3.0]
# In box helper
# in Else  [19.0]
# bbox returned by getBbox  {'label': [2.0], 'height': [42.0], 'top': [3.0], 'width': [19.0], 'left': [35.0]}
# n =  59
# BB  <HDF5 object reference>
# In box helper
# in If  [20.0, 20.0]
# In box helper
# in If  [4.0, 7.0]
# In box helper
# in If  [16.0, 25.0]
# In box helper
# in If  [1.0, 1.0]
# In box helper
# in If  [9.0, 7.0]
# bbox returned by getBbox  {'label': [4.0, 7.0], 'height': [20.0, 20.0], 'top': [1.0, 1.0], 'width': [9.0, 7.0], 'left': [16.0, 25.0]}
# n =  60
# BB  <HDF5 object reference>
# In box helper
# in Else  [19.0]
# In box helper
# in Else  [5.0]
# In box helper
# in Else  [33.0]
# In box helper
# in Else  [6.0]
# In box helper
# in Else  [9.0]
# bbox returned by getBbox  {'label': [5.0], 'height': [19.0], 'top': [6.0], 'width': [9.0], 'left': [33.0]}
# n =  61
# BB  <HDF5 object reference>
# In box helper
# in If  [46.0, 46.0]
# In box helper
# in If  [3.0, 2.0]
# In box helper
# in If  [45.0, 61.0]
# In box helper
# in If  [6.0, 8.0]
# In box helper
# in If  [24.0, 25.0]
# bbox returned by getBbox  {'label': [3.0, 2.0], 'height': [46.0, 46.0], 'top': [6.0, 8.0], 'width': [24.0, 25.0], 'left': [45.0, 61.0]}
# n =  62
# BB  <HDF5 object reference>
# In box helper
# in If  [63.0, 63.0]
# In box helper
# in If  [4.0, 3.0]
# In box helper
# in If  [96.0, 132.0]
# In box helper
# in If  [23.0, 27.0]
# In box helper
# in If  [40.0, 37.0]
# bbox returned by getBbox  {'label': [4.0, 3.0], 'height': [63.0, 63.0], 'top': [23.0, 27.0], 'width': [40.0, 37.0], 'left': [96.0, 132.0]}
# n =  63
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0]
# In box helper
# in If  [2.0, 9.0]
# In box helper
# in If  [26.0, 37.0]
# In box helper
# in If  [4.0, 3.0]
# In box helper
# in If  [8.0, 16.0]
# bbox returned by getBbox  {'label': [2.0, 9.0], 'height': [26.0, 26.0], 'top': [4.0, 3.0], 'width': [8.0, 16.0], 'left': [26.0, 37.0]}
# n =  64
# BB  <HDF5 object reference>
# In box helper
# in If  [21.0, 21.0]
# In box helper
# in If  [5.0, 8.0]
# In box helper
# in If  [25.0, 36.0]
# In box helper
# in If  [6.0, 7.0]
# In box helper
# in If  [11.0, 12.0]
# bbox returned by getBbox  {'label': [5.0, 8.0], 'height': [21.0, 21.0], 'top': [6.0, 7.0], 'width': [11.0, 12.0], 'left': [25.0, 36.0]}
# n =  65
# BB  <HDF5 object reference>
# In box helper
# in If  [30.0, 30.0]
# In box helper
# in If  [9.0, 5.0]
# In box helper
# in If  [38.0, 46.0]
# In box helper
# in If  [6.0, 6.0]
# In box helper
# in If  [11.0, 14.0]
# bbox returned by getBbox  {'label': [9.0, 5.0], 'height': [30.0, 30.0], 'top': [6.0, 6.0], 'width': [11.0, 14.0], 'left': [38.0, 46.0]}
# n =  66
# BB  <HDF5 object reference>
# In box helper
# in If  [47.0, 47.0]
# In box helper
# in If  [1.0, 10.0]
# In box helper
# in If  [48.0, 59.0]
# In box helper
# in If  [5.0, 4.0]
# In box helper
# in If  [12.0, 22.0]
# bbox returned by getBbox  {'label': [1.0, 10.0], 'height': [47.0, 47.0], 'top': [5.0, 4.0], 'width': [12.0, 22.0], 'left': [48.0, 59.0]}
# n =  67
# BB  <HDF5 object reference>
# In box helper
# in If  [35.0, 35.0, 35.0]
# In box helper
# in If  [5.0, 4.0, 2.0]
# In box helper
# in If  [71.0, 88.0, 102.0]
# In box helper
# in If  [19.0, 19.0, 14.0]
# In box helper
# in If  [14.0, 13.0, 20.0]
# bbox returned by getBbox  {'label': [5.0, 4.0, 2.0], 'height': [35.0, 35.0, 35.0], 'top': [19.0, 19.0, 14.0], 'width': [14.0, 13.0, 20.0], 'left': [71.0, 88.0, 102.0]}
# n =  68
# BB  <HDF5 object reference>
# In box helper
# in If  [46.0, 46.0]
# In box helper
# in If  [4.0, 4.0]
# In box helper
# in If  [54.0, 67.0]
# In box helper
# in If  [12.0, 16.0]
# In box helper
# in If  [15.0, 14.0]
# bbox returned by getBbox  {'label': [4.0, 4.0], 'height': [46.0, 46.0], 'top': [12.0, 16.0], 'width': [15.0, 14.0], 'left': [54.0, 67.0]}
# n =  69
# BB  <HDF5 object reference>
# In box helper
# in If  [16.0, 16.0]
# In box helper
# in If  [3.0, 1.0]
# In box helper
# in If  [20.0, 30.0]
# In box helper
# in If  [5.0, 5.0]
# In box helper
# in If  [11.0, 7.0]
# bbox returned by getBbox  {'label': [3.0, 1.0], 'height': [16.0, 16.0], 'top': [5.0, 5.0], 'width': [11.0, 7.0], 'left': [20.0, 30.0]}
# n =  70
# BB  <HDF5 object reference>
# In box helper
# in If  [22.0, 22.0, 22.0, 22.0]
# In box helper
# in If  [2.0, 3.0, 8.0, 6.0]
# In box helper
# in If  [24.0, 36.0, 48.0, 58.0]
# In box helper
# in If  [4.0, 4.0, 3.0, 3.0]
# In box helper
# in If  [11.0, 10.0, 9.0, 10.0]
# bbox returned by getBbox  {'label': [2.0, 3.0, 8.0, 6.0], 'height': [22.0, 22.0, 22.0, 22.0], 'top': [4.0, 4.0, 3.0, 3.0], 'width': [11.0, 10.0, 9.0, 10.0], 'left': [24.0, 36.0, 48.0, 58.0]}
# n =  71
# BB  <HDF5 object reference>
# In box helper
# in If  [17.0, 17.0]
# In box helper
# in If  [1.0, 5.0]
# In box helper
# in If  [26.0, 34.0]
# In box helper
# in If  [6.0, 5.0]
# In box helper
# in If  [7.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 5.0], 'height': [17.0, 17.0], 'top': [6.0, 5.0], 'width': [7.0, 11.0], 'left': [26.0, 34.0]}
# n =  72
# BB  <HDF5 object reference>
# In box helper
# in Else  [14.0]
# In box helper
# in Else  [3.0]
# In box helper
# in Else  [18.0]
# In box helper
# in Else  [3.0]
# In box helper
# in Else  [5.0]
# bbox returned by getBbox  {'label': [3.0], 'height': [14.0], 'top': [3.0], 'width': [5.0], 'left': [18.0]}
# n =  73
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0]
# In box helper
# in If  [3.0, 3.0]
# In box helper
# in If  [28.0, 40.0]
# In box helper
# in If  [4.0, 6.0]
# In box helper
# in If  [10.0, 12.0]
# bbox returned by getBbox  {'label': [3.0, 3.0], 'height': [26.0, 26.0], 'top': [4.0, 6.0], 'width': [10.0, 12.0], 'left': [28.0, 40.0]}
# n =  74
# BB  <HDF5 object reference>
# In box helper
# in If  [29.0, 29.0]
# In box helper
# in If  [1.0, 8.0]
# In box helper
# in If  [34.0, 40.0]
# In box helper
# in If  [10.0, 9.0]
# In box helper
# in If  [7.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 8.0], 'height': [29.0, 29.0], 'top': [10.0, 9.0], 'width': [7.0, 11.0], 'left': [34.0, 40.0]}
# n =  75
# BB  <HDF5 object reference>
# In box helper
# in If  [18.0, 18.0]
# In box helper
# in If  [9.0, 8.0]
# In box helper
# in If  [22.0, 29.0]
# In box helper
# in If  [2.0, 2.0]
# In box helper
# in If  [6.0, 6.0]
# bbox returned by getBbox  {'label': [9.0, 8.0], 'height': [18.0, 18.0], 'top': [2.0, 2.0], 'width': [6.0, 6.0], 'left': [22.0, 29.0]}
# n =  76
# BB  <HDF5 object reference>
# In box helper
# in If  [60.0, 60.0, 60.0]
# In box helper
# in If  [7.0, 3.0, 9.0]
# In box helper
# in If  [53.0, 84.0, 106.0]
# In box helper
# in If  [5.0, 4.0, 6.0]
# In box helper
# in If  [30.0, 24.0, 24.0]
# bbox returned by getBbox  {'label': [7.0, 3.0, 9.0], 'height': [60.0, 60.0, 60.0], 'top': [5.0, 4.0, 6.0], 'width': [30.0, 24.0, 24.0], 'left': [53.0, 84.0, 106.0]}
# n =  77
# BB  <HDF5 object reference>
# In box helper
# in If  [22.0, 22.0, 22.0]
# In box helper
# in If  [1.0, 3.0, 8.0]
# In box helper
# in If  [78.0, 86.0, 93.0]
# In box helper
# in If  [14.0, 14.0, 12.0]
# In box helper
# in If  [9.0, 8.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 3.0, 8.0], 'height': [22.0, 22.0, 22.0], 'top': [14.0, 14.0, 12.0], 'width': [9.0, 8.0, 11.0], 'left': [78.0, 86.0, 93.0]}
# n =  78
# BB  <HDF5 object reference>
# In box helper
# in If  [51.0, 51.0, 51.0, 51.0]
# In box helper
# in If  [1.0, 9.0, 2.0, 2.0]
# In box helper
# in If  [40.0, 64.0, 99.0, 138.0]
# In box helper
# in If  [41.0, 33.0, 17.0, 11.0]
# In box helper
# in If  [22.0, 30.0, 35.0, 31.0]
# bbox returned by getBbox  {'label': [1.0, 9.0, 2.0, 2.0], 'height': [51.0, 51.0, 51.0, 51.0], 'top': [41.0, 33.0, 17.0, 11.0], 'width': [22.0, 30.0, 35.0, 31.0], 'left': [40.0, 64.0, 99.0, 138.0]}
# n =  79
# BB  <HDF5 object reference>
# In box helper
# in If  [19.0, 19.0]
# In box helper
# in If  [2.0, 2.0]
# In box helper
# in If  [38.0, 54.0]
# In box helper
# in If  [11.0, 8.0]
# In box helper
# in If  [12.0, 16.0]
# bbox returned by getBbox  {'label': [2.0, 2.0], 'height': [19.0, 19.0], 'top': [11.0, 8.0], 'width': [12.0, 16.0], 'left': [38.0, 54.0]}
# n =  80
# BB  <HDF5 object reference>
# In box helper
# in If  [31.0, 31.0]
# In box helper
# in If  [7.0, 4.0]
# In box helper
# in If  [49.0, 64.0]
# In box helper
# in If  [8.0, 7.0]
# In box helper
# in If  [14.0, 17.0]
# bbox returned by getBbox  {'label': [7.0, 4.0], 'height': [31.0, 31.0], 'top': [8.0, 7.0], 'width': [14.0, 17.0], 'left': [49.0, 64.0]}
# n =  81
# BB  <HDF5 object reference>
# In box helper
# in If  [30.0, 30.0]
# In box helper
# in If  [4.0, 5.0]
# In box helper
# in If  [35.0, 54.0]
# In box helper
# in If  [8.0, 6.0]
# In box helper
# in If  [19.0, 18.0]
# bbox returned by getBbox  {'label': [4.0, 5.0], 'height': [30.0, 30.0], 'top': [8.0, 6.0], 'width': [19.0, 18.0], 'left': [35.0, 54.0]}
# n =  82
# BB  <HDF5 object reference>
# In box helper
# in If  [29.0, 29.0]
# In box helper
# in If  [6.0, 10.0]
# In box helper
# in If  [36.0, 53.0]
# In box helper
# in If  [6.0, 15.0]
# In box helper
# in If  [16.0, 12.0]
# bbox returned by getBbox  {'label': [6.0, 10.0], 'height': [29.0, 29.0], 'top': [6.0, 15.0], 'width': [16.0, 12.0], 'left': [36.0, 53.0]}
# n =  83
# BB  <HDF5 object reference>
# In box helper
# in Else  [32.0]
# In box helper
# in Else  [3.0]
# In box helper
# in Else  [34.0]
# In box helper
# in Else  [6.0]
# In box helper
# in Else  [20.0]
# bbox returned by getBbox  {'label': [3.0], 'height': [32.0], 'top': [6.0], 'width': [20.0], 'left': [34.0]}
# n =  84
# BB  <HDF5 object reference>
# In box helper
# in If  [15.0, 15.0]
# In box helper
# in If  [1.0, 7.0]
# In box helper
# in If  [17.0, 23.0]
# In box helper
# in If  [7.0, 6.0]
# In box helper
# in If  [6.0, 7.0]
# bbox returned by getBbox  {'label': [1.0, 7.0], 'height': [15.0, 15.0], 'top': [7.0, 6.0], 'width': [6.0, 7.0], 'left': [17.0, 23.0]}
# n =  85
# BB  <HDF5 object reference>
# In box helper
# in If  [20.0, 20.0]
# In box helper
# in If  [3.0, 5.0]
# In box helper
# in If  [26.0, 33.0]
# In box helper
# in If  [4.0, 5.0]
# In box helper
# in If  [7.0, 9.0]
# bbox returned by getBbox  {'label': [3.0, 5.0], 'height': [20.0, 20.0], 'top': [4.0, 5.0], 'width': [7.0, 9.0], 'left': [26.0, 33.0]}
# n =  86
# BB  <HDF5 object reference>
# In box helper
# in If  [35.0, 35.0]
# In box helper
# in If  [1.0, 7.0]
# In box helper
# in If  [67.0, 81.0]
# In box helper
# in If  [16.0, 17.0]
# In box helper
# in If  [14.0, 24.0]
# bbox returned by getBbox  {'label': [1.0, 7.0], 'height': [35.0, 35.0], 'top': [16.0, 17.0], 'width': [14.0, 24.0], 'left': [67.0, 81.0]}
# n =  87
# BB  <HDF5 object reference>
# In box helper
# in Else  [36.0]
# In box helper
# in Else  [5.0]
# In box helper
# in Else  [47.0]
# In box helper
# in Else  [13.0]
# In box helper
# in Else  [27.0]
# bbox returned by getBbox  {'label': [5.0], 'height': [36.0], 'top': [13.0], 'width': [27.0], 'left': [47.0]}
# n =  88
# BB  <HDF5 object reference>
# In box helper
# in If  [64.0, 64.0]
# In box helper
# in If  [1.0, 8.0]
# In box helper
# in If  [85.0, 110.0]
# In box helper
# in If  [23.0, 19.0]
# In box helper
# in If  [26.0, 33.0]
# bbox returned by getBbox  {'label': [1.0, 8.0], 'height': [64.0, 64.0], 'top': [23.0, 19.0], 'width': [26.0, 33.0], 'left': [85.0, 110.0]}
# n =  89
# BB  <HDF5 object reference>
# In box helper
# in If  [30.0, 30.0, 30.0]
# In box helper
# in If  [1.0, 6.0, 4.0]
# In box helper
# in If  [37.0, 46.0, 61.0]
# In box helper
# in If  [6.0, 7.0, 10.0]
# In box helper
# in If  [6.0, 13.0, 13.0]
# bbox returned by getBbox  {'label': [1.0, 6.0, 4.0], 'height': [30.0, 30.0, 30.0], 'top': [6.0, 7.0, 10.0], 'width': [6.0, 13.0, 13.0], 'left': [37.0, 46.0, 61.0]}
# n =  90
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0, 26.0]
# In box helper
# in If  [1.0, 9.0, 3.0]
# In box helper
# in If  [49.0, 59.0, 68.0]
# In box helper
# in If  [18.0, 17.0, 13.0]
# In box helper
# in If  [9.0, 11.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 9.0, 3.0], 'height': [26.0, 26.0, 26.0], 'top': [18.0, 17.0, 13.0], 'width': [9.0, 11.0, 11.0], 'left': [49.0, 59.0, 68.0]}
# n =  91
# BB  <HDF5 object reference>
# In box helper
# in If  [35.0, 35.0]
# In box helper
# in If  [3.0, 5.0]
# In box helper
# in If  [35.0, 56.0]
# In box helper
# in If  [6.0, 8.0]
# In box helper
# in If  [19.0, 14.0]
# bbox returned by getBbox  {'label': [3.0, 5.0], 'height': [35.0, 35.0], 'top': [6.0, 8.0], 'width': [19.0, 14.0], 'left': [35.0, 56.0]}
# n =  92
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0]
# In box helper
# in If  [1.0, 7.0]
# In box helper
# in If  [40.0, 51.0]
# In box helper
# in If  [11.0, 7.0]
# In box helper
# in If  [12.0, 19.0]
# bbox returned by getBbox  {'label': [1.0, 7.0], 'height': [32.0, 32.0], 'top': [11.0, 7.0], 'width': [12.0, 19.0], 'left': [40.0, 51.0]}
# n =  93
# BB  <HDF5 object reference>
# In box helper
# in If  [34.0, 34.0]
# In box helper
# in If  [1.0, 2.0]
# In box helper
# in If  [54.0, 67.0]
# In box helper
# in If  [18.0, 12.0]
# In box helper
# in If  [12.0, 19.0]
# bbox returned by getBbox  {'label': [1.0, 2.0], 'height': [34.0, 34.0], 'top': [18.0, 12.0], 'width': [12.0, 19.0], 'left': [54.0, 67.0]}
# n =  94
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0, 26.0, 26.0]
# In box helper
# in If  [1.0, 10.0, 4.0, 4.0]
# In box helper
# in If  [127.0, 136.0, 148.0, 157.0]
# In box helper
# in If  [58.0, 60.0, 60.0, 59.0]
# In box helper
# in If  [10.0, 9.0, 11.0, 10.0]
# bbox returned by getBbox  {'label': [1.0, 10.0, 4.0, 4.0], 'height': [26.0, 26.0, 26.0, 26.0], 'top': [58.0, 60.0, 60.0, 59.0], 'width': [10.0, 9.0, 11.0, 10.0], 'left': [127.0, 136.0, 148.0, 157.0]}
# n =  95
# BB  <HDF5 object reference>
# In box helper
# in If  [39.0, 39.0]
# In box helper
# in If  [1.0, 8.0]
# In box helper
# in If  [33.0, 56.0]
# In box helper
# in If  [6.0, 5.0]
# In box helper
# in If  [23.0, 32.0]
# bbox returned by getBbox  {'label': [1.0, 8.0], 'height': [39.0, 39.0], 'top': [6.0, 5.0], 'width': [23.0, 32.0], 'left': [33.0, 56.0]}
# n =  96
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0]
# In box helper
# in If  [3.0, 6.0]
# In box helper
# in If  [34.0, 48.0]
# In box helper
# in If  [8.0, 6.0]
# In box helper
# in If  [16.0, 14.0]
# bbox returned by getBbox  {'label': [3.0, 6.0], 'height': [32.0, 32.0], 'top': [8.0, 6.0], 'width': [16.0, 14.0], 'left': [34.0, 48.0]}
# n =  97
# BB  <HDF5 object reference>
# In box helper
# in If  [37.0, 37.0, 37.0]
# In box helper
# in If  [1.0, 2.0, 10.0]
# In box helper
# in If  [50.0, 66.0, 85.0]
# In box helper
# in If  [7.0, 7.0, 11.0]
# In box helper
# in If  [15.0, 21.0, 27.0]
# bbox returned by getBbox  {'label': [1.0, 2.0, 10.0], 'height': [37.0, 37.0, 37.0], 'top': [7.0, 7.0, 11.0], 'width': [15.0, 21.0, 27.0], 'left': [50.0, 66.0, 85.0]}
# n =  98
# BB  <HDF5 object reference>
# In box helper
# in Else  [29.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [30.0]
# In box helper
# in Else  [4.0]
# In box helper
# in Else  [17.0]
# bbox returned by getBbox  {'label': [2.0], 'height': [29.0], 'top': [4.0], 'width': [17.0], 'left': [30.0]}
# n =  99
# BB  <HDF5 object reference>
# In box helper
# in If  [22.0, 22.0, 22.0]
# In box helper
# in If  [1.0, 10.0, 9.0]
# In box helper
# in If  [18.0, 23.0, 32.0]
# In box helper
# in If  [1.0, 0.0, 0.0]
# In box helper
# in If  [5.0, 9.0, 10.0]
# bbox returned by getBbox  {'label': [1.0, 10.0, 9.0], 'height': [22.0, 22.0, 22.0], 'top': [1.0, 0.0, 0.0], 'width': [5.0, 9.0, 10.0], 'left': [18.0, 23.0, 32.0]}
# n =  100
# BB  <HDF5 object reference>
# In box helper
# in If  [27.0, 27.0]
# In box helper
# in If  [5.0, 3.0]
# In box helper
# in If  [27.0, 42.0]
# In box helper
# in If  [7.0, 5.0]
# In box helper
# in If  [13.0, 12.0]
# bbox returned by getBbox  {'label': [5.0, 3.0], 'height': [27.0, 27.0], 'top': [7.0, 5.0], 'width': [13.0, 12.0], 'left': [27.0, 42.0]}
# n =  101
# BB  <HDF5 object reference>
# In box helper
# in If  [51.0, 51.0]
# In box helper
# in If  [3.0, 5.0]
# In box helper
# in If  [58.0, 77.0]
# In box helper
# in If  [14.0, 9.0]
# In box helper
# in If  [18.0, 16.0]
# bbox returned by getBbox  {'label': [3.0, 5.0], 'height': [51.0, 51.0], 'top': [14.0, 9.0], 'width': [18.0, 16.0], 'left': [58.0, 77.0]}
# n =  102
# BB  <HDF5 object reference>
# In box helper
# in Else  [28.0]
# In box helper
# in Else  [7.0]
# In box helper
# in Else  [54.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [20.0]
# bbox returned by getBbox  {'label': [7.0], 'height': [28.0], 'top': [2.0], 'width': [20.0], 'left': [54.0]}
# n =  103
# BB  <HDF5 object reference>
# In box helper
# in If  [69.0, 69.0, 69.0]
# In box helper
# in If  [1.0, 10.0, 4.0]
# In box helper
# in If  [67.0, 99.0, 122.0]
# In box helper
# in If  [18.0, 20.0, 12.0]
# In box helper
# in If  [29.0, 21.0, 26.0]
# bbox returned by getBbox  {'label': [1.0, 10.0, 4.0], 'height': [69.0, 69.0, 69.0], 'top': [18.0, 20.0, 12.0], 'width': [29.0, 21.0, 26.0], 'left': [67.0, 99.0, 122.0]}
# n =  104
# BB  <HDF5 object reference>
# In box helper
# in If  [100.0, 100.0]
# In box helper
# in If  [1.0, 4.0]
# In box helper
# in If  [83.0, 128.0]
# In box helper
# in If  [13.0, 10.0]
# In box helper
# in If  [44.0, 69.0]
# bbox returned by getBbox  {'label': [1.0, 4.0], 'height': [100.0, 100.0], 'top': [13.0, 10.0], 'width': [44.0, 69.0], 'left': [83.0, 128.0]}
# n =  105
# BB  <HDF5 object reference>
# In box helper
# in If  [17.0, 17.0]
# In box helper
# in If  [1.0, 4.0]
# In box helper
# in If  [37.0, 49.0]
# In box helper
# in If  [12.0, 12.0]
# In box helper
# in If  [10.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 4.0], 'height': [17.0, 17.0], 'top': [12.0, 12.0], 'width': [10.0, 11.0], 'left': [37.0, 49.0]}
# n =  106
# BB  <HDF5 object reference>
# In box helper
# in If  [29.0, 29.0]
# In box helper
# in If  [5.0, 2.0]
# In box helper
# in If  [49.0, 64.0]
# In box helper
# in If  [16.0, 13.0]
# In box helper
# in If  [14.0, 16.0]
# bbox returned by getBbox  {'label': [5.0, 2.0], 'height': [29.0, 29.0], 'top': [16.0, 13.0], 'width': [14.0, 16.0], 'left': [49.0, 64.0]}
# n =  107
# BB  <HDF5 object reference>
# In box helper
# in Else  [27.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [28.0]
# In box helper
# in Else  [3.0]
# In box helper
# in Else  [14.0]
# bbox returned by getBbox  {'label': [2.0], 'height': [27.0], 'top': [3.0], 'width': [14.0], 'left': [28.0]}
# n =  108
# BB  <HDF5 object reference>
# In box helper
# in If  [28.0, 28.0]
# In box helper
# in If  [3.0, 10.0]
# In box helper
# in If  [38.0, 57.0]
# In box helper
# in If  [11.0, 10.0]
# In box helper
# in If  [18.0, 14.0]
# bbox returned by getBbox  {'label': [3.0, 10.0], 'height': [28.0, 28.0], 'top': [11.0, 10.0], 'width': [18.0, 14.0], 'left': [38.0, 57.0]}
# n =  109
# BB  <HDF5 object reference>
# In box helper
# in If  [18.0, 18.0]
# In box helper
# in If  [6.0, 3.0]
# In box helper
# in If  [16.0, 27.0]
# In box helper
# in If  [1.0, 1.0]
# In box helper
# in If  [10.0, 11.0]
# bbox returned by getBbox  {'label': [6.0, 3.0], 'height': [18.0, 18.0], 'top': [1.0, 1.0], 'width': [10.0, 11.0], 'left': [16.0, 27.0]}
# n =  110
# BB  <HDF5 object reference>
# In box helper
# in Else  [20.0]
# In box helper
# in Else  [9.0]
# In box helper
# in Else  [23.0]
# In box helper
# in Else  [8.0]
# In box helper
# in Else  [11.0]
# bbox returned by getBbox  {'label': [9.0], 'height': [20.0], 'top': [8.0], 'width': [11.0], 'left': [23.0]}
# n =  111
# BB  <HDF5 object reference>
# In box helper
# in If  [37.0, 37.0, 37.0]
# In box helper
# in If  [1.0, 8.0, 7.0]
# In box helper
# in If  [31.0, 44.0, 63.0]
# In box helper
# in If  [2.0, 1.0, 6.0]
# In box helper
# in If  [14.0, 21.0, 19.0]
# bbox returned by getBbox  {'label': [1.0, 8.0, 7.0], 'height': [37.0, 37.0, 37.0], 'top': [2.0, 1.0, 6.0], 'width': [14.0, 21.0, 19.0], 'left': [31.0, 44.0, 63.0]}
# n =  112
# BB  <HDF5 object reference>
# In box helper
# in If  [21.0, 21.0]
# In box helper
# in If  [1.0, 3.0]
# In box helper
# in If  [19.0, 27.0]
# In box helper
# in If  [1.0, 3.0]
# In box helper
# in If  [8.0, 12.0]
# bbox returned by getBbox  {'label': [1.0, 3.0], 'height': [21.0, 21.0], 'top': [1.0, 3.0], 'width': [8.0, 12.0], 'left': [19.0, 27.0]}
# n =  113
# BB  <HDF5 object reference>
# In box helper
# in If  [28.0, 28.0]
# In box helper
# in If  [1.0, 9.0]
# In box helper
# in If  [29.0, 37.0]
# In box helper
# in If  [6.0, 4.0]
# In box helper
# in If  [7.0, 10.0]
# bbox returned by getBbox  {'label': [1.0, 9.0], 'height': [28.0, 28.0], 'top': [6.0, 4.0], 'width': [7.0, 10.0], 'left': [29.0, 37.0]}
# n =  114
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0]
# In box helper
# in If  [3.0, 2.0]
# In box helper
# in If  [26.0, 38.0]
# In box helper
# in If  [1.0, 1.0]
# In box helper
# in If  [9.0, 13.0]
# bbox returned by getBbox  {'label': [3.0, 2.0], 'height': [26.0, 26.0], 'top': [1.0, 1.0], 'width': [9.0, 13.0], 'left': [26.0, 38.0]}
# n =  115
# BB  <HDF5 object reference>
# In box helper
# in If  [14.0, 14.0, 14.0]
# In box helper
# in If  [5.0, 1.0, 3.0]
# In box helper
# in If  [27.0, 34.0, 40.0]
# In box helper
# in If  [12.0, 12.0, 11.0]
# In box helper
# in If  [8.0, 6.0, 9.0]
# bbox returned by getBbox  {'label': [5.0, 1.0, 3.0], 'height': [14.0, 14.0, 14.0], 'top': [12.0, 12.0, 11.0], 'width': [8.0, 6.0, 9.0], 'left': [27.0, 34.0, 40.0]}
# n =  116
# BB  <HDF5 object reference>
# In box helper
# in If  [145.0, 145.0]
# In box helper
# in If  [4.0, 8.0]
# In box helper
# in If  [145.0, 224.0]
# In box helper
# in If  [8.0, 13.0]
# In box helper
# in If  [79.0, 87.0]
# bbox returned by getBbox  {'label': [4.0, 8.0], 'height': [145.0, 145.0], 'top': [8.0, 13.0], 'width': [79.0, 87.0], 'left': [145.0, 224.0]}
# n =  117
# BB  <HDF5 object reference>
# In box helper
# in If  [15.0, 15.0, 15.0, 15.0]
# In box helper
# in If  [3.0, 4.0, 2.0, 1.0]
# In box helper
# in If  [13.0, 22.0, 31.0, 40.0]
# In box helper
# in If  [2.0, 2.0, 1.0, 1.0]
# In box helper
# in If  [9.0, 9.0, 9.0, 7.0]
# bbox returned by getBbox  {'label': [3.0, 4.0, 2.0, 1.0], 'height': [15.0, 15.0, 15.0, 15.0], 'top': [2.0, 2.0, 1.0, 1.0], 'width': [9.0, 9.0, 9.0, 7.0], 'left': [13.0, 22.0, 31.0, 40.0]}
# n =  118
# BB  <HDF5 object reference>
# In box helper
# in If  [48.0, 48.0, 48.0]
# In box helper
# in If  [3.0, 2.0, 3.0]
# In box helper
# in If  [91.0, 113.0, 135.0]
# In box helper
# in If  [55.0, 44.0, 33.0]
# In box helper
# in If  [27.0, 29.0, 39.0]
# bbox returned by getBbox  {'label': [3.0, 2.0, 3.0], 'height': [48.0, 48.0, 48.0], 'top': [55.0, 44.0, 33.0], 'width': [27.0, 29.0, 39.0], 'left': [91.0, 113.0, 135.0]}
# n =  119
# BB  <HDF5 object reference>
# In box helper
# in If  [40.0, 40.0]
# In box helper
# in If  [5.0, 1.0]
# In box helper
# in If  [65.0, 84.0]
# In box helper
# in If  [20.0, 20.0]
# In box helper
# in If  [24.0, 17.0]
# bbox returned by getBbox  {'label': [5.0, 1.0], 'height': [40.0, 40.0], 'top': [20.0, 20.0], 'width': [24.0, 17.0], 'left': [65.0, 84.0]}
# n =  120
# BB  <HDF5 object reference>
# In box helper
# in If  [21.0, 21.0, 21.0, 21.0]
# In box helper
# in If  [1.0, 3.0, 5.0, 8.0]
# In box helper
# in If  [32.0, 43.0, 63.0, 79.0]
# In box helper
# in If  [8.0, 8.0, 7.0, 7.0]
# In box helper
# in If  [6.0, 13.0, 11.0, 13.0]
# bbox returned by getBbox  {'label': [1.0, 3.0, 5.0, 8.0], 'height': [21.0, 21.0, 21.0, 21.0], 'top': [8.0, 8.0, 7.0, 7.0], 'width': [6.0, 13.0, 11.0, 13.0], 'left': [32.0, 43.0, 63.0, 79.0]}
# n =  121
# BB  <HDF5 object reference>
# In box helper
# in If  [23.0, 23.0]
# In box helper
# in If  [1.0, 7.0]
# In box helper
# in If  [21.0, 26.0]
# In box helper
# in If  [2.0, 1.0]
# In box helper
# in If  [4.0, 5.0]
# bbox returned by getBbox  {'label': [1.0, 7.0], 'height': [23.0, 23.0], 'top': [2.0, 1.0], 'width': [4.0, 5.0], 'left': [21.0, 26.0]}
# n =  122
# BB  <HDF5 object reference>
# In box helper
# in Else  [22.0]
# In box helper
# in Else  [6.0]
# In box helper
# in Else  [25.0]
# In box helper
# in Else  [5.0]
# In box helper
# in Else  [10.0]
# bbox returned by getBbox  {'label': [6.0], 'height': [22.0], 'top': [5.0], 'width': [10.0], 'left': [25.0]}
# n =  123
# BB  <HDF5 object reference>
# In box helper
# in Else  [23.0]
# In box helper
# in Else  [5.0]
# In box helper
# in Else  [19.0]
# In box helper
# in Else  [1.0]
# In box helper
# in Else  [10.0]
# bbox returned by getBbox  {'label': [5.0], 'height': [23.0], 'top': [1.0], 'width': [10.0], 'left': [19.0]}
# n =  124
# BB  <HDF5 object reference>
# In box helper
# in If  [17.0, 17.0]
# In box helper
# in If  [6.0, 4.0]
# In box helper
# in If  [18.0, 23.0]
# In box helper
# in If  [3.0, 3.0]
# In box helper
# in If  [6.0, 10.0]
# bbox returned by getBbox  {'label': [6.0, 4.0], 'height': [17.0, 17.0], 'top': [3.0, 3.0], 'width': [6.0, 10.0], 'left': [18.0, 23.0]}
# n =  125
# BB  <HDF5 object reference>
# In box helper
# in If  [52.0, 52.0, 52.0]
# In box helper
# in If  [1.0, 10.0, 8.0]
# In box helper
# in If  [56.0, 72.0, 97.0]
# In box helper
# in If  [14.0, 12.0, 8.0]
# In box helper
# in If  [15.0, 22.0, 21.0]
# bbox returned by getBbox  {'label': [1.0, 10.0, 8.0], 'height': [52.0, 52.0, 52.0], 'top': [14.0, 12.0, 8.0], 'width': [15.0, 22.0, 21.0], 'left': [56.0, 72.0, 97.0]}
# n =  126
# BB  <HDF5 object reference>
# In box helper
# in Else  [36.0]
# In box helper
# in Else  [8.0]
# In box helper
# in Else  [32.0]
# In box helper
# in Else  [15.0]
# In box helper
# in Else  [16.0]
# bbox returned by getBbox  {'label': [8.0], 'height': [36.0], 'top': [15.0], 'width': [16.0], 'left': [32.0]}
# n =  127
# BB  <HDF5 object reference>
# In box helper
# in If  [45.0, 45.0]
# In box helper
# in If  [1.0, 3.0]
# In box helper
# in If  [56.0, 65.0]
# In box helper
# in If  [16.0, 22.0]
# In box helper
# in If  [9.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 3.0], 'height': [45.0, 45.0], 'top': [16.0, 22.0], 'width': [9.0, 11.0], 'left': [56.0, 65.0]}
# n =  128
# BB  <HDF5 object reference>
# In box helper
# in If  [17.0, 17.0]
# In box helper
# in If  [6.0, 8.0]
# In box helper
# in If  [21.0, 29.0]
# In box helper
# in If  [5.0, 5.0]
# In box helper
# in If  [8.0, 9.0]
# bbox returned by getBbox  {'label': [6.0, 8.0], 'height': [17.0, 17.0], 'top': [5.0, 5.0], 'width': [8.0, 9.0], 'left': [21.0, 29.0]}
# n =  129
# BB  <HDF5 object reference>
# In box helper
# in Else  [21.0]
# In box helper
# in Else  [4.0]
# In box helper
# in Else  [26.0]
# In box helper
# in Else  [4.0]
# In box helper
# in Else  [17.0]
# bbox returned by getBbox  {'label': [4.0], 'height': [21.0], 'top': [4.0], 'width': [17.0], 'left': [26.0]}
# n =  130
# BB  <HDF5 object reference>
# In box helper
# in If  [18.0, 18.0, 18.0]
# In box helper
# in If  [1.0, 7.0, 4.0]
# In box helper
# in If  [24.0, 32.0, 44.0]
# In box helper
# in If  [6.0, 5.0, 5.0]
# In box helper
# in If  [8.0, 11.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 7.0, 4.0], 'height': [18.0, 18.0, 18.0], 'top': [6.0, 5.0, 5.0], 'width': [8.0, 11.0, 11.0], 'left': [24.0, 32.0, 44.0]}
# n =  131
# BB  <HDF5 object reference>
# In box helper
# in If  [67.0, 67.0]
# In box helper
# in If  [9.0, 8.0]
# In box helper
# in If  [78.0, 122.0]
# In box helper
# in If  [20.0, 8.0]
# In box helper
# in If  [43.0, 36.0]
# bbox returned by getBbox  {'label': [9.0, 8.0], 'height': [67.0, 67.0], 'top': [20.0, 8.0], 'width': [43.0, 36.0], 'left': [78.0, 122.0]}
# n =  132
# BB  <HDF5 object reference>
# In box helper
# in If  [99.0, 99.0]
# In box helper
# in If  [4.0, 4.0]
# In box helper
# in If  [91.0, 132.0]
# In box helper
# in If  [13.0, 14.0]
# In box helper
# in If  [43.0, 44.0]
# bbox returned by getBbox  {'label': [4.0, 4.0], 'height': [99.0, 99.0], 'top': [13.0, 14.0], 'width': [43.0, 44.0], 'left': [91.0, 132.0]}
# n =  133
# BB  <HDF5 object reference>
# In box helper
# in Else  [14.0]
# In box helper
# in Else  [9.0]
# In box helper
# in Else  [16.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [9.0]
# bbox returned by getBbox  {'label': [9.0], 'height': [14.0], 'top': [2.0], 'width': [9.0], 'left': [16.0]}
# n =  134
# BB  <HDF5 object reference>
# In box helper
# in If  [28.0, 28.0]
# In box helper
# in If  [6.0, 8.0]
# In box helper
# in If  [26.0, 41.0]
# In box helper
# in If  [2.0, 3.0]
# In box helper
# in If  [13.0, 12.0]
# bbox returned by getBbox  {'label': [6.0, 8.0], 'height': [28.0, 28.0], 'top': [2.0, 3.0], 'width': [13.0, 12.0], 'left': [26.0, 41.0]}
# n =  135
# BB  <HDF5 object reference>
# In box helper
# in Else  [37.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [52.0]
# In box helper
# in Else  [10.0]
# In box helper
# in Else  [15.0]
# bbox returned by getBbox  {'label': [2.0], 'height': [37.0], 'top': [10.0], 'width': [15.0], 'left': [52.0]}
# n =  136
# BB  <HDF5 object reference>
# In box helper
# in If  [43.0, 43.0]
# In box helper
# in If  [1.0, 10.0]
# In box helper
# in If  [50.0, 70.0]
# In box helper
# in If  [10.0, 10.0]
# In box helper
# in If  [14.0, 17.0]
# bbox returned by getBbox  {'label': [1.0, 10.0], 'height': [43.0, 43.0], 'top': [10.0, 10.0], 'width': [14.0, 17.0], 'left': [50.0, 70.0]}
# n =  137
# ...
# n =  1346
# BB  <HDF5 object reference>
# In box helper
# in If  [43.0, 43.0]
# In box helper
# in If  [3.0, 6.0]
# In box helper
# in If  [41.0, 60.0]
# In box helper
# in If  [4.0, 6.0]
# In box helper
# in If  [21.0, 25.0]
# bbox returned by getBbox  {'label': [3.0, 6.0], 'height': [43.0, 43.0], 'top': [4.0, 6.0], 'width': [21.0, 25.0], 'left': [41.0, 60.0]}
# n =  1347
# BB  <HDF5 object reference>
# In box helper
# in If  [56.0, 56.0, 56.0]
# In box helper
# in If  [1.0, 1.0, 8.0]
# In box helper
# in If  [107.0, 133.0, 148.0]
# In box helper
# in If  [76.0, 69.0, 62.0]
# In box helper
# in If  [32.0, 21.0, 35.0]
# bbox returned by getBbox  {'label': [1.0, 1.0, 8.0], 'height': [56.0, 56.0, 56.0], 'top': [76.0, 69.0, 62.0], 'width': [32.0, 21.0, 35.0], 'left': [107.0, 133.0, 148.0]}
# n =  1348
# BB  <HDF5 object reference>
# In box helper
# in If  [20.0, 20.0]
# In box helper
# in If  [8.0, 4.0]
# In box helper
# in If  [27.0, 37.0]
# In box helper
# in If  [5.0, 5.0]
# In box helper
# in If  [10.0, 7.0]
# bbox returned by getBbox  {'label': [8.0, 4.0], 'height': [20.0, 20.0], 'top': [5.0, 5.0], 'width': [10.0, 7.0], 'left': [27.0, 37.0]}
# n =  1349
# BB  <HDF5 object reference>
# In box helper
# in If  [18.0, 18.0, 18.0]
# In box helper
# in If  [3.0, 10.0, 3.0]
# In box helper
# in If  [46.0, 55.0, 64.0]
# In box helper
# in If  [15.0, 15.0, 15.0]
# In box helper
# in If  [8.0, 8.0, 6.0]
# bbox returned by getBbox  {'label': [3.0, 10.0, 3.0], 'height': [18.0, 18.0, 18.0], 'top': [15.0, 15.0, 15.0], 'width': [8.0, 8.0, 6.0], 'left': [46.0, 55.0, 64.0]}
# n =  1350
# BB  <HDF5 object reference>
# In box helper
# in If  [17.0, 17.0, 17.0]
# In box helper
# in If  [4.0, 1.0, 10.0]
# In box helper
# in If  [18.0, 27.0, 33.0]
# In box helper
# in If  [2.0, 4.0, 3.0]
# In box helper
# in If  [8.0, 5.0, 7.0]
# bbox returned by getBbox  {'label': [4.0, 1.0, 10.0], 'height': [17.0, 17.0, 17.0], 'top': [2.0, 4.0, 3.0], 'width': [8.0, 5.0, 7.0], 'left': [18.0, 27.0, 33.0]}
# n =  1351
# BB  <HDF5 object reference>
# In box helper
# in If  [21.0, 21.0]
# In box helper
# in If  [3.0, 3.0]
# In box helper
# in If  [74.0, 89.0]
# In box helper
# in If  [20.0, 19.0]
# In box helper
# in If  [14.0, 14.0]
# bbox returned by getBbox  {'label': [3.0, 3.0], 'height': [21.0, 21.0], 'top': [20.0, 19.0], 'width': [14.0, 14.0], 'left': [74.0, 89.0]}
# n =  1352
# BB  <HDF5 object reference>
# In box helper
# in Else  [31.0]
# In box helper
# in Else  [5.0]
# In box helper
# in Else  [46.0]
# In box helper
# in Else  [11.0]
# In box helper
# in Else  [17.0]
# bbox returned by getBbox  {'label': [5.0], 'height': [31.0], 'top': [11.0], 'width': [17.0], 'left': [46.0]}
# n =  1353
# BB  <HDF5 object reference>
# In box helper
# in If  [66.0, 66.0]
# In box helper
# in If  [4.0, 1.0]
# In box helper
# in If  [80.0, 113.0]
# In box helper
# in If  [18.0, 19.0]
# In box helper
# in If  [32.0, 32.0]
# bbox returned by getBbox  {'label': [4.0, 1.0], 'height': [66.0, 66.0], 'top': [18.0, 19.0], 'width': [32.0, 32.0], 'left': [80.0, 113.0]}
# n =  1354
# BB  <HDF5 object reference>
# In box helper
# in If  [24.0, 24.0]
# In box helper
# in If  [3.0, 8.0]
# In box helper
# in If  [28.0, 43.0]
# In box helper
# in If  [5.0, 5.0]
# In box helper
# in If  [14.0, 12.0]
# bbox returned by getBbox  {'label': [3.0, 8.0], 'height': [24.0, 24.0], 'top': [5.0, 5.0], 'width': [14.0, 12.0], 'left': [28.0, 43.0]}
# n =  1355
# BB  <HDF5 object reference>
# In box helper
# in If  [50.0, 50.0]
# In box helper
# in If  [1.0, 10.0]
# In box helper
# in If  [46.0, 65.0]
# In box helper
# in If  [4.0, 7.0]
# In box helper
# in If  [15.0, 33.0]
# bbox returned by getBbox  {'label': [1.0, 10.0], 'height': [50.0, 50.0], 'top': [4.0, 7.0], 'width': [15.0, 33.0], 'left': [46.0, 65.0]}
# n =  1356
# BB  <HDF5 object reference>
# In box helper
# in If  [18.0, 18.0, 18.0]
# In box helper
# in If  [2.0, 9.0, 6.0]
# In box helper
# in If  [18.0, 25.0, 33.0]
# In box helper
# in If  [1.0, 1.0, 1.0]
# In box helper
# in If  [7.0, 8.0, 8.0]
# bbox returned by getBbox  {'label': [2.0, 9.0, 6.0], 'height': [18.0, 18.0, 18.0], 'top': [1.0, 1.0, 1.0], 'width': [7.0, 8.0, 8.0], 'left': [18.0, 25.0, 33.0]}
# n =  1357
# BB  <HDF5 object reference>
# In box helper
# in If  [19.0, 19.0]
# In box helper
# in If  [3.0, 8.0]
# In box helper
# in If  [24.0, 33.0]
# In box helper
# in If  [5.0, 6.0]
# In box helper
# in If  [9.0, 10.0]
# bbox returned by getBbox  {'label': [3.0, 8.0], 'height': [19.0, 19.0], 'top': [5.0, 6.0], 'width': [9.0, 10.0], 'left': [24.0, 33.0]}
# n =  1358
# BB  <HDF5 object reference>
# In box helper
# in If  [70.0, 70.0]
# In box helper
# in If  [3.0, 6.0]
# In box helper
# in If  [59.0, 93.0]
# In box helper
# in If  [11.0, 9.0]
# In box helper
# in If  [36.0, 39.0]
# bbox returned by getBbox  {'label': [3.0, 6.0], 'height': [70.0, 70.0], 'top': [11.0, 9.0], 'width': [36.0, 39.0], 'left': [59.0, 93.0]}
# n =  1359
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0, 32.0, 32.0]
# In box helper
# in If  [2.0, 7.0, 5.0, 7.0]
# In box helper
# in If  [40.0, 53.0, 63.0, 73.0]
# In box helper
# in If  [8.0, 5.0, 4.0, 7.0]
# In box helper
# in If  [12.0, 8.0, 9.0, 8.0]
# bbox returned by getBbox  {'label': [2.0, 7.0, 5.0, 7.0], 'height': [32.0, 32.0, 32.0, 32.0], 'top': [8.0, 5.0, 4.0, 7.0], 'width': [12.0, 8.0, 9.0, 8.0], 'left': [40.0, 53.0, 63.0, 73.0]}
# n =  1360
# BB  <HDF5 object reference>
# In box helper
# in If  [42.0, 42.0, 42.0, 42.0]
# In box helper
# in If  [1.0, 1.0, 7.0, 10.0]
# In box helper
# in If  [65.0, 86.0, 101.0, 140.0]
# In box helper
# in If  [15.0, 15.0, 15.0, 20.0]
# In box helper
# in If  [18.0, 14.0, 35.0, 27.0]
# bbox returned by getBbox  {'label': [1.0, 1.0, 7.0, 10.0], 'height': [42.0, 42.0, 42.0, 42.0], 'top': [15.0, 15.0, 15.0, 20.0], 'width': [18.0, 14.0, 35.0, 27.0], 'left': [65.0, 86.0, 101.0, 140.0]}
# n =  1361
# BB  <HDF5 object reference>
# In box helper
# in If  [24.0, 24.0]
# In box helper
# in If  [1.0, 8.0]
# In box helper
# in If  [29.0, 41.0]
# In box helper
# in If  [6.0, 7.0]
# In box helper
# in If  [6.0, 11.0]
# bbox returned by getBbox  {'label': [1.0, 8.0], 'height': [24.0, 24.0], 'top': [6.0, 7.0], 'width': [6.0, 11.0], 'left': [29.0, 41.0]}
# n =  1362
# BB  <HDF5 object reference>
# In box helper
# in If  [50.0, 50.0]
# In box helper
# in If  [5.0, 8.0]
# In box helper
# in If  [61.0, 81.0]
# In box helper
# in If  [21.0, 20.0]
# In box helper
# in If  [23.0, 25.0]
# bbox returned by getBbox  {'label': [5.0, 8.0], 'height': [50.0, 50.0], 'top': [21.0, 20.0], 'width': [23.0, 25.0], 'left': [61.0, 81.0]}
# n =  1363
# BB  <HDF5 object reference>
# In box helper
# in If  [36.0, 36.0]
# In box helper
# in If  [4.0, 1.0]
# In box helper
# in If  [46.0, 64.0]
# In box helper
# in If  [16.0, 16.0]
# In box helper
# in If  [20.0, 13.0]
# bbox returned by getBbox  {'label': [4.0, 1.0], 'height': [36.0, 36.0], 'top': [16.0, 16.0], 'width': [20.0, 13.0], 'left': [46.0, 64.0]}
# n =  1364
# BB  <HDF5 object reference>
# In box helper
# in Else  [22.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [42.0]
# In box helper
# in Else  [10.0]
# In box helper
# in Else  [14.0]
# bbox returned by getBbox  {'label': [2.0], 'height': [22.0], 'top': [10.0], 'width': [14.0], 'left': [42.0]}
# n =  1365
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0]
# In box helper
# in If  [5.0, 10.0]
# In box helper
# in If  [38.0, 55.0]
# In box helper
# in If  [9.0, 9.0]
# In box helper
# in If  [18.0, 16.0]
# bbox returned by getBbox  {'label': [5.0, 10.0], 'height': [26.0, 26.0], 'top': [9.0, 9.0], 'width': [18.0, 16.0], 'left': [38.0, 55.0]}
# n =  1366
# BB  <HDF5 object reference>
# In box helper
# in Else  [35.0]
# In box helper
# in Else  [5.0]
# In box helper
# in Else  [34.0]
# In box helper
# in Else  [6.0]
# In box helper
# in Else  [19.0]
# bbox returned by getBbox  {'label': [5.0], 'height': [35.0], 'top': [6.0], 'width': [19.0], 'left': [34.0]}
# n =  1367
# BB  <HDF5 object reference>
# In box helper
# in If  [20.0, 20.0]
# In box helper
# in If  [4.0, 10.0]
# In box helper
# in If  [47.0, 58.0]
# In box helper
# in If  [15.0, 14.0]
# In box helper
# in If  [12.0, 15.0]
# bbox returned by getBbox  {'label': [4.0, 10.0], 'height': [20.0, 20.0], 'top': [15.0, 14.0], 'width': [12.0, 15.0], 'left': [47.0, 58.0]}
# n =  1368
# BB  <HDF5 object reference>
# In box helper
# in If  [35.0, 35.0, 35.0]
# In box helper
# in If  [2.0, 10.0, 7.0]
# In box helper
# in If  [31.0, 44.0, 55.0]
# In box helper
# in If  [2.0, 3.0, 3.0]
# In box helper
# in If  [15.0, 14.0, 13.0]
# bbox returned by getBbox  {'label': [2.0, 10.0, 7.0], 'height': [35.0, 35.0, 35.0], 'top': [2.0, 3.0, 3.0], 'width': [15.0, 14.0, 13.0], 'left': [31.0, 44.0, 55.0]}
# n =  1369
# BB  <HDF5 object reference>
# In box helper
# in If  [17.0, 17.0, 17.0, 17.0]
# In box helper
# in If  [2.0, 3.0, 3.0, 10.0]
# In box helper
# in If  [26.0, 35.0, 45.0, 55.0]
# In box helper
# in If  [3.0, 3.0, 2.0, 3.0]
# In box helper
# in If  [9.0, 8.0, 9.0, 8.0]
# bbox returned by getBbox  {'label': [2.0, 3.0, 3.0, 10.0], 'height': [17.0, 17.0, 17.0, 17.0], 'top': [3.0, 3.0, 2.0, 3.0], 'width': [9.0, 8.0, 9.0, 8.0], 'left': [26.0, 35.0, 45.0, 55.0]}
# n =  1370
# BB  <HDF5 object reference>
# In box helper
# in If  [24.0, 24.0]
# In box helper
# in If  [2.0, 3.0]
# In box helper
# in If  [23.0, 30.0]
# In box helper
# in If  [3.0, 5.0]
# In box helper
# in If  [6.0, 10.0]
# bbox returned by getBbox  {'label': [2.0, 3.0], 'height': [24.0, 24.0], 'top': [3.0, 5.0], 'width': [6.0, 10.0], 'left': [23.0, 30.0]}
# n =  1371
# BB  <HDF5 object reference>
# In box helper
# in If  [27.0, 27.0, 27.0]
# In box helper
# in If  [9.0, 1.0, 3.0]
# In box helper
# in If  [35.0, 48.0, 59.0]
# In box helper
# in If  [4.0, 6.0, 7.0]
# In box helper
# in If  [13.0, 10.0, 15.0]
# bbox returned by getBbox  {'label': [9.0, 1.0, 3.0], 'height': [27.0, 27.0, 27.0], 'top': [4.0, 6.0, 7.0], 'width': [13.0, 10.0, 15.0], 'left': [35.0, 48.0, 59.0]}
# n =  1372
# BB  <HDF5 object reference>
# In box helper
# in If  [21.0, 21.0, 21.0]
# In box helper
# in If  [1.0, 5.0, 10.0]
# In box helper
# in If  [18.0, 33.0, 51.0]
# In box helper
# in If  [1.0, 0.0, 0.0]
# In box helper
# in If  [10.0, 18.0, 18.0]
# bbox returned by getBbox  {'label': [1.0, 5.0, 10.0], 'height': [21.0, 21.0, 21.0], 'top': [1.0, 0.0, 0.0], 'width': [10.0, 18.0, 18.0], 'left': [18.0, 33.0, 51.0]}
# n =  1373
# BB  <HDF5 object reference>
# In box helper
# in If  [14.0, 14.0, 14.0]
# In box helper
# in If  [3.0, 1.0, 5.0]
# In box helper
# in If  [18.0, 27.0, 33.0]
# In box helper
# in If  [3.0, 3.0, 3.0]
# In box helper
# in If  [9.0, 5.0, 8.0]
# bbox returned by getBbox  {'label': [3.0, 1.0, 5.0], 'height': [14.0, 14.0, 14.0], 'top': [3.0, 3.0, 3.0], 'width': [9.0, 5.0, 8.0], 'left': [18.0, 27.0, 33.0]}
# n =  1374
# BB  <HDF5 object reference>
# In box helper
# in If  [21.0, 21.0]
# In box helper
# in If  [9.0, 10.0]
# In box helper
# in If  [28.0, 40.0]
# In box helper
# in If  [6.0, 6.0]
# In box helper
# in If  [14.0, 14.0]
# bbox returned by getBbox  {'label': [9.0, 10.0], 'height': [21.0, 21.0], 'top': [6.0, 6.0], 'width': [14.0, 14.0], 'left': [28.0, 40.0]}
# n =  1375
# BB  <HDF5 object reference>
# In box helper
# in If  [36.0, 36.0, 36.0]
# In box helper
# in If  [1.0, 3.0, 4.0]
# In box helper
# in If  [91.0, 104.0, 122.0]
# In box helper
# in If  [37.0, 29.0, 19.0]
# In box helper
# in If  [19.0, 19.0, 21.0]
# bbox returned by getBbox  {'label': [1.0, 3.0, 4.0], 'height': [36.0, 36.0, 36.0], 'top': [37.0, 29.0, 19.0], 'width': [19.0, 19.0, 21.0], 'left': [91.0, 104.0, 122.0]}
# n =  1376
# BB  <HDF5 object reference>
# In box helper
# in If  [23.0, 23.0]
# In box helper
# in If  [4.0, 5.0]
# In box helper
# in If  [23.0, 33.0]
# In box helper
# in If  [1.0, 1.0]
# In box helper
# in If  [9.0, 8.0]
# bbox returned by getBbox  {'label': [4.0, 5.0], 'height': [23.0, 23.0], 'top': [1.0, 1.0], 'width': [9.0, 8.0], 'left': [23.0, 33.0]}
# n =  1377
# BB  <HDF5 object reference>
# In box helper
# in If  [28.0, 28.0]
# In box helper
# in If  [1.0, 10.0]
# In box helper
# in If  [32.0, 38.0]
# In box helper
# in If  [7.0, 7.0]
# In box helper
# in If  [6.0, 12.0]
# bbox returned by getBbox  {'label': [1.0, 10.0], 'height': [28.0, 28.0], 'top': [7.0, 7.0], 'width': [6.0, 12.0], 'left': [32.0, 38.0]}
# n =  1378
# BB  <HDF5 object reference>
# In box helper
# in If  [15.0, 15.0, 15.0, 15.0]
# In box helper
# in If  [2.0, 3.0, 5.0, 9.0]
# In box helper
# in If  [15.0, 24.0, 32.0, 39.0]
# In box helper
# in If  [1.0, 1.0, 1.0, 1.0]
# In box helper
# in If  [9.0, 8.0, 8.0, 8.0]
# bbox returned by getBbox  {'label': [2.0, 3.0, 5.0, 9.0], 'height': [15.0, 15.0, 15.0, 15.0], 'top': [1.0, 1.0, 1.0, 1.0], 'width': [9.0, 8.0, 8.0, 8.0], 'left': [15.0, 24.0, 32.0, 39.0]}
# n =  1379
# BB  <HDF5 object reference>
# In box helper
# in If  [12.0, 12.0, 12.0]
# In box helper
# in If  [1.0, 9.0, 10.0]
# In box helper
# in If  [18.0, 22.0, 30.0]
# In box helper
# in If  [2.0, 3.0, 3.0]
# In box helper
# in If  [5.0, 7.0, 6.0]
# bbox returned by getBbox  {'label': [1.0, 9.0, 10.0], 'height': [12.0, 12.0, 12.0], 'top': [2.0, 3.0, 3.0], 'width': [5.0, 7.0, 6.0], 'left': [18.0, 22.0, 30.0]}
# n =  1380
# BB  <HDF5 object reference>
# In box helper
# in If  [26.0, 26.0]
# In box helper
# in If  [4.0, 5.0]
# In box helper
# in If  [23.0, 34.0]
# In box helper
# in If  [3.0, 2.0]
# In box helper
# in If  [14.0, 17.0]
# bbox returned by getBbox  {'label': [4.0, 5.0], 'height': [26.0, 26.0], 'top': [3.0, 2.0], 'width': [14.0, 17.0], 'left': [23.0, 34.0]}
# n =  1381
# BB  <HDF5 object reference>
# In box helper
# in If  [56.0, 56.0, 56.0]
# In box helper
# in If  [1.0, 3.0, 6.0]
# In box helper
# in If  [40.0, 62.0, 92.0]
# In box helper
# in If  [1.0, 5.0, 1.0]
# In box helper
# in If  [26.0, 29.0, 29.0]
# bbox returned by getBbox  {'label': [1.0, 3.0, 6.0], 'height': [56.0, 56.0, 56.0], 'top': [1.0, 5.0, 1.0], 'width': [26.0, 29.0, 29.0], 'left': [40.0, 62.0, 92.0]}
# n =  1382
# BB  <HDF5 object reference>
# In box helper
# in Else  [58.0]
# In box helper
# in Else  [8.0]
# In box helper
# in Else  [60.0]
# In box helper
# in Else  [12.0]
# In box helper
# in Else  [33.0]
# bbox returned by getBbox  {'label': [8.0], 'height': [58.0], 'top': [12.0], 'width': [33.0], 'left': [60.0]}
# n =  1383
# BB  <HDF5 object reference>
# In box helper
# in If  [35.0, 35.0]
# In box helper
# in If  [6.0, 2.0]
# In box helper
# in If  [44.0, 60.0]
# In box helper
# in If  [6.0, 7.0]
# In box helper
# in If  [15.0, 18.0]
# bbox returned by getBbox  {'label': [6.0, 2.0], 'height': [35.0, 35.0], 'top': [6.0, 7.0], 'width': [15.0, 18.0], 'left': [44.0, 60.0]}
# n =  1384
# BB  <HDF5 object reference>
# In box helper
# in If  [25.0, 25.0]
# In box helper
# in If  [1.0, 9.0]
# In box helper
# in If  [22.0, 30.0]
# In box helper
# in If  [3.0, 3.0]
# In box helper
# in If  [8.0, 12.0]
# bbox returned by getBbox  {'label': [1.0, 9.0], 'height': [25.0, 25.0], 'top': [3.0, 3.0], 'width': [8.0, 12.0], 'left': [22.0, 30.0]}
# n =  1385
# BB  <HDF5 object reference>
# In box helper
# in Else  [17.0]
# In box helper
# in Else  [10.0]
# In box helper
# in Else  [2.0]
# In box helper
# in Else  [4.0]
# In box helper
# in Else  [9.0]
# bbox returned by getBbox  {'label': [10.0], 'height': [17.0], 'top': [4.0], 'width': [9.0], 'left': [2.0]}
# n =  1386
# BB  <HDF5 object reference>
# In box helper
# in If  [22.0, 22.0]
# In box helper
# in If  [4.0, 10.0]
# In box helper
# in If  [33.0, 44.0]
# In box helper
# in If  [9.0, 9.0]
# In box helper
# in If  [12.0, 10.0]
# bbox returned by getBbox  {'label': [4.0, 10.0], 'height': [22.0, 22.0], 'top': [9.0, 9.0], 'width': [12.0, 10.0], 'left': [33.0, 44.0]}
# n =  1387
# BB  <HDF5 object reference>
# In box helper
# in If  [25.0, 25.0]
# In box helper
# in If  [2.0, 7.0]
# In box helper
# in If  [30.0, 42.0]
# In box helper
# in If  [6.0, 7.0]
# In box helper
# in If  [13.0, 11.0]
# bbox returned by getBbox  {'label': [2.0, 7.0], 'height': [25.0, 25.0], 'top': [6.0, 7.0], 'width': [13.0, 11.0], 'left': [30.0, 42.0]}
# n =  1388
# BB  <HDF5 object reference>
# In box helper
# in If  [32.0, 32.0]
# In box helper
# in If  [3.0, 6.0]
# In box helper
# in If  [33.0, 48.0]
# In box helper
# in If  [5.0, 7.0]
# In box helper
# in If  [13.0, 15.0]
# bbox returned by getBbox  {'label': [3.0, 6.0], 'height': [32.0, 32.0], 'top': [5.0, 7.0], 'width': [13.0, 15.0], 'left': [33.0, 48.0]}
# n =  1389
# BB  <HDF5 object reference>
# In box helper
# in If  [24.0, 24.0]
# In box helper
# in If  [3.0, 10.0]
# In box helper
# in If  [28.0, 46.0]
# In box helper
# in If  [5.0, 6.0]
# In box helper
# in If  [15.0, 13.0]
# bbox returned by getBbox  {'label': [3.0, 10.0], 'height': [24.0, 24.0], 'top': [5.0, 6.0], 'width': [15.0, 13.0], 'left': [28.0, 46.0]}
# n =  1390
# BB  <HDF5 object reference>
# In box helper
# in If  [27.0, 27.0]
# In box helper
# in If

# %%
# Note train_data is list of dictionary
train_data[0]
# Out:
# {'boxes': [{'height': 219.0,
#    'label': 1.0,
#    'left': 246.0,
#    'top': 77.0,
#    'width': 81.0},
#   {'height': 219.0, 'label': 9.0, 'left': 323.0, 'top': 81.0, 'width': 96.0}],
#  'filename': '1.png'}

# %%
train_data[24] # This has digit 601 on it, Note how this is misclassified
# Out:
# {'boxes': [{'height': 50.0,
#    'label': 6.0,
#    'left': 60.0,
#    'top': 11.0,
#    'width': 24.0},
#   {'height': 50.0, 'label': 10.0, 'left': 87.0, 'top': 9.0, 'width': 24.0},
#   {'height': 50.0, 'label': 1.0, 'left': 113.0, 'top': 7.0, 'width': 21.0}],
#  'filename': '25.png'}

# %%
train_data[21] # Has digit 515 on it. Note how height and top are the same (makes absolute sense)
# Out:
# {'boxes': [{'height': 16.0,
#    'label': 5.0,
#    'left': 24.0,
#    'top': 4.0,
#    'width': 10.0},
#   {'height': 16.0, 'label': 1.0, 'left': 34.0, 'top': 5.0, 'width': 7.0},
#   {'height': 16.0, 'label': 5.0, 'left': 40.0, 'top': 5.0, 'width': 11.0}],
#  'filename': '22.png'}

# %%
train_data[21]['boxes']
# Out:
# [{'height': 16.0, 'label': 5.0, 'left': 24.0, 'top': 4.0, 'width': 10.0},
#  {'height': 16.0, 'label': 1.0, 'left': 34.0, 'top': 5.0, 'width': 7.0},
#  {'height': 16.0, 'label': 5.0, 'left': 40.0, 'top': 5.0, 'width': 11.0}]

# %%
train_data[21]['boxes'][0]['label']
# Out:
# 5.0

# %%
train_data[21]['filename']
# Out:
# '22.png'

# %% [markdown]
# ### Crop images using bounded box information

# %% [raw]
# # PIL
# #PIL is the Python Imaging Library(in newer versions known as Pillow)
#
# #Adds support for opening, manipulating, and saving many different image file formats.
#
# #The Image module provides a class with the same name which is used to represent a PIL image. The module also provides a number of factory functions, including functions to load images from files, and to create new images.
#
# from PIL import Image
# im = Image.open("F:\\Aegis\\Python\\Jupyter Notebook\\Projects\\SVHM\\train\\58.jpg")
# im.rotate(45).show()

# %%
pwd
# Out:
# 'F:\\Aegis\\Python\\Jupyter Notebook\\Projects\\SVHM'

# %%
from PIL import Image
fname = os.path.join('train','1.png')
im = Image.open(fname)
im.rotate(45).show()
print(im.size[:])
# Out:
# (741, 350)

# %%
from PIL import Image

#Creating a numpy array with rows = number of images and 2 columns
train_imsize = np.ndarray([len(train_data),2])
#print("Sample ",train_imsize[0:5,:])

for i in range(len(train_data)):
    filename = train_data[i]['filename']
    #print(filename)
    fullname = os.path.join('train',filename)
    im = Image.open(fullname)
    #im.show()
    train_imsize[i,:] = im.size[:] #getting size of the image width, height
    if i == 10:
        break

#print(train_imsize[0:5,:])
#print(np.amax(train_imsize[:,0]), np.amax(train_imsize[:,1]))
#print(np.amin(train_imsize[:,0]), np.amin(train_imsize[:,1]))
print(train_imsize)
# Out:
# [[741. 350.]]

# %%
a = np.ndarray([2,3])
a
l = im.size[:]
print(l)
im.show()
# Out:
# (63, 33)

# %%
test_imsize = np.ndarray([len(test_data),2])
for i in np.arange(len(test_data)):
    filename = test_data[i]['filename']
    fullname = os.path.join('test', filename)
    im = Image.open(fullname)
    test_imsize[i, :] = im.size[:]

print(np.amax(test_imsize[:,0]), np.amax(test_imsize[:,1]))
print(np.amin(test_imsize[:,0]), np.amin(test_imsize[:,1]))
# Out:
# 1083.0 516.0
# 31.0 13.0

# %%
extra_imsize = np.ndarray([len(extra_data),2])
for i in np.arange(len(extra_data)):
    filename = extra_data[i]['filename']
    fullname = os.path.join('extra', filename)
    im = Image.open(fullname)
    extra_imsize[i, :] = im.size[:]

print(np.amax(extra_imsize[:,0]), np.amax(extra_imsize[:,1]))
print(np.amin(extra_imsize[:,0]), np.amin(extra_imsize[:,1]))
# Out:
# 668.0 415.0
# 22.0 13.0

# %% [markdown]
# ### Distribute extra image dataset and remove images with more than 5 digits

# %%
# Reference for data pre-processing in images
#https://becominghuman.ai/image-data-pre-processing-for-neural-networks-498289068258
import PIL.Image as Image

def generate_dataset(data, folder):
    dataset = np.ndarray([len(data),32,32,1], dtype='float32') #initialize an array to store gray scale images
    labels = np.ones([len(data),6], dtype=int) * 10 #initialize an array of n*6 with value 10
    for i in np.arange(len(data)): #can use range function also, np.arange or range 
        filename = data[i]['filename']
        fullname = os.path.join(folder, filename)
        im = Image.open(fullname)
        boxes = data[i]['boxes'] #returns list of dictionaries of number of digits
        num_digit = len(boxes) 
        labels[i,0] = num_digit
        print("labels ",labels)
        top = np.ndarray([num_digit], dtype='float32') #create a array of 1*n type
        print("top ",top)
        left = np.ndarray([num_digit], dtype='float32') #create a array of 1*n type
        height = np.ndarray([num_digit], dtype='float32')
        width = np.ndarray([num_digit], dtype='float32')
        print("width ",width)
        for j in np.arange(num_digit):
            if j < 5: 
                labels[i,j+1] = boxes[j]['label']
                if boxes[j]['label'] == 10:
                    labels[i,j+1] = 0
            else:
                print('Image number ',i,' has more than 5 digits')
            #Storing top, left, width, height of all the digits of the image in a list
            top[j] = boxes[j]['top']
            left[j] = boxes[j]['left']
            height[j] = boxes[j]['height']
            width[j] = boxes[j]['width']
        
        im_top = np.amin(top)
        im_left = np.amin(left)
        im_height = np.amax(top) + height[np.argmax(top)] - im_top
        im_width = np.amax(left) + width[np.argmax(left)] - im_left
        
        im_top = np.floor(im_top - 0.1 * im_height)
        im_left = np.floor(im_left - 0.1 * im_width)
        im_bottom = np.amin([np.ceil(im_top + 1.2 * im_height), im.size[1]])
        im_right = np.amin([np.ceil(im_left + 1.2 * im_width), im.size[0]])
        
        '''
        Uniform aspect ratio: One of the first steps is to ensure that the images have the same size and aspect ratio. 
        Most of the neural network models assume a square shape input image, which means that each image needs to be checked 
        if it is a square or not, and cropped appropriately. Cropping can be done to select a square part of the image.
        While cropping, we usually care about the part in the center.
        '''
        
        ''' crop the image using the bounded info and resize it to 32*32 
        Image.resize(size, resample=0), by default PIL.Image.ANTIALIAS (a high-quality downsampling filter). 
        If omitted, or if the image has mode “1” or “P”, it is set PIL.Image.NEAREST
        '''
        '''
        Image Scaling: Once we’ve ensured that all images are square (or have some predetermined aspect ratio), 
        it’s time to scale each image appropriately. 
        '''
        
        im = im.crop((im_left, im_top, im_right, im_bottom)).resize([32,32], Image.ANTIALIAS) 
        # to convert RGB to gray image Y' = 0.2989 R + 0.5870 G + 0.1140 B  or img = Image.open('image.png').convert('LA')
        '''
        Dimensionality reduction: We could choose to collapse the RGB channels into a single gray-scale channel. 
        There are often considerations to reduce other dimensions, when the neural network performance is allowed to be
        invariant to that dimension, or to make the training problem more tractable.
        '''
        im = np.dot(np.array(im, dtype='float32'), [[0.2989],[0.5870],[0.1140]])
        
        '''Data normalization is an important step which ensures that each input parameter (pixel, in this case) has a similar
        data distribution. This makes convergence faster while training the network. 
        Data normalization is done by subtracting the mean from each pixel and then dividing the result by the standard deviation. 
        The distribution of such data would resemble a Gaussian curve centered at zero. 
        For image inputs we need the pixel numbers to be positive, so we might choose to scale the 
        normalized data in the range [0,1] or [0, 255]. 
        '''
        mean = np.mean(im, dtype='float32')
        std = np.std(im, dtype='float32', ddof=1)
        if std < 1e-4:
            std = 1
        im = (im - mean) / std
        dataset[i,:,:,:] = im[:,:,:]

    return dataset, labels

train_dataset, train_labels = generate_dataset(train_data, 'train')
print(train_dataset.shape, train_labels.shape)

test_dataset, test_labels = generate_dataset(test_data, 'test')
print(test_dataset.shape, test_labels.shape)

extra_dataset, extra_labels = generate_dataset(extra_data, 'extra')
print(extra_dataset.shape, extra_labels.shape)
# Out:
# # 29929 image has more than 5 digits.
# (33402, 32, 32, 1) (33402, 6)
# (13068, 32, 32, 1) (13068, 6)
# (202353, 32, 32, 1) (202353, 6)

# %%
print(np.ones([5,6], dtype=int)*10)
print(np.ndarray([5], dtype='float32'))
np.floor(3.5)
# Out:
# [[10 10 10 10 10 10]
#  [10 10 10 10 10 10]
#  [10 10 10 10 10 10]
#  [10 10 10 10 10 10]
#  [10 10 10 10 10 10]]
# [ 9. 11. 10. 13. 13.]
# 3.0

# %%
d = [2,3,4,4]
for i in range(len(d)):
    print(d[i])
# Out:
# 2
# 3
# 4
# 4

# %%
dataset = np.array([5,1], dtype='float32')
dataset
# Out:
# array([5., 1.], dtype=float32)

# %%
dataset = np.ndarray([4,3,2,1], dtype='float32')
dataset
# Out:
# array([[[[ 0.0000000e+00],
#          [ 3.2421875e+00]],
#
#         [[ 0.0000000e+00],
#          [ 3.0078125e+00]],
#
#         [[-4.9272309e+26],
#          [ 2.7762154e+25]]],
#
#
#        [[[ 1.8931001e-17],
#          [ 4.8344797e-43]],
#
#         [[ 1.3443311e+33],
#          [ 4.8344797e-43]],
#
#         [[-3.5975111e-07],
#          [-1.4201790e+18]]],
#
#
#        [[[ 0.0000000e+00],
#          [ 0.0000000e+00]],
#
#         [[ 0.0000000e+00],
#          [ 0.0000000e+00]],
#
#         [[ 0.0000000e+00],
#          [ 0.0000000e+00]]],
#
#
#        [[[ 0.0000000e+00],
#          [ 0.0000000e+00]],
#
#         [[ 0.0000000e+00],
#          [ 0.0000000e+00]],
#
#         [[ 0.0000000e+00],
#          [ 0.0000000e+00]]]], dtype=float32)

# %%
t = [2,3,4,5]
np.argmax(t)+np.max(t)
# Out:
# 8

# %%
#len(train_dataset)
train_dataset[0]

# %%
train_dataset = np.delete(train_dataset, 29929, axis=0)
train_labels = np.delete(train_labels, 29929, axis=0)

print(train_dataset.shape, train_labels.shape)
# Out:
# (33401, 32, 32, 1) (33401, 6)

# %%
import random

random.seed()

n_labels = 10
valid_index = []
valid_index2 = []
train_index = []
train_index2 = []
for i in np.arange(n_labels):
    valid_index.extend(np.where(train_labels[:,1] == (i))[0][:400].tolist())
    train_index.extend(np.where(train_labels[:,1] == (i))[0][400:].tolist())
    valid_index2.extend(np.where(extra_labels[:,1] == (i))[0][:200].tolist())
    train_index2.extend(np.where(extra_labels[:,1] == (i))[0][200:].tolist())

random.shuffle(valid_index)
random.shuffle(train_index)
random.shuffle(valid_index2)
random.shuffle(train_index2)

valid_dataset = np.concatenate((extra_dataset[valid_index2,:,:,:], train_dataset[valid_index,:,:,:]), axis=0)
valid_labels = np.concatenate((extra_labels[valid_index2,:], train_labels[valid_index,:]), axis=0)
train_dataset_t = np.concatenate((extra_dataset[train_index2,:,:,:], train_dataset[train_index,:,:,:]), axis=0)
train_labels_t = np.concatenate((extra_labels[train_index2,:], train_labels[train_index,:]), axis=0)

print(train_dataset_t.shape, train_labels_t.shape)
print(test_dataset.shape, test_labels.shape)
print(valid_dataset.shape, valid_labels.shape)
# Out:
# (230070, 32, 32, 1) (230070, 6)
# (13068, 32, 32, 1) (13068, 6)
# (5684, 32, 32, 1) (5684, 6)

# %%
"""Create a pickle file to store processed data"""
pickle_file = 'SVHN_multi.pickle'

try:
    f = open(pickle_file, 'wb')
    dict_data = {
    'train_dataset': train_dataset_t,
    'train_labels': train_labels_t,
    'valid_dataset': valid_dataset,
    'valid_labels': valid_labels,
    'test_dataset': test_dataset,
    'test_labels': test_labels,
    }
    pickle.dump(dict_data, f, pickle.HIGHEST_PROTOCOL)
    f.close()
except Exception as e:
    print('Unable to save data to', pickle_file, ':', e)
    
statinfo = os.stat(pickle_file)
print('Compressed pickle size:', statinfo.st_size)
# Out:
# Compressed pickle size: 1025147176
